# %% [markdown]
# Read FiftyDatasets/AllDatasetsInfo/AllDataSourcesInfo/Kaggle/Sato/ Viznet datasets

# %%
import pandas as pd
from datetime import datetime
import re  

DB_or_dataset = input("Insert if using Datasets (d), Database.tables (dt), the two Data Sources (ds), Kaggle Datasets (k), Kaggle Datasets to correct (kc), Sato Datasets (s), Sato Filtered (sf), Filtered Viznet Datasets (v), or Filtered Kaggle Viznet Datasets (kv): ")

print(DB_or_dataset)

if DB_or_dataset.lower() == 'd':
    print("Using Datasets")
    datasets_xlsx = pd.read_excel("FiftyDatasets.xlsx") 
    columns_xlsx = pd.read_excel("AllColumnsFromFiftyDatasets.xlsx")
    analysed_columns_file_path = 'AnalysedColumns.xlsx'     
elif DB_or_dataset.lower() == 'dt':
    print("Using Database tables")
    datasets_xlsx = pd.read_excel("AllDatasetsInfo.xlsx")
    columns_xlsx = pd.read_excel("AllColumnsInfo.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDB.xlsx'
elif DB_or_dataset.lower() == 'ds':
    print("Using Datasets and Database tables")
    datasets_xlsx = pd.read_excel("AllDataSourcesInfo.xlsx")
    columns_xlsx = pd.read_excel("AllAttributes_andColumnsInfo.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDS.xlsx'
elif DB_or_dataset.lower() == 'k':
    print("Using Kaggle Datasets")
    datasets_xlsx = pd.read_excel("kaggle_datasets_with_domain_and_match.xlsx")
    columns_xlsx = pd.read_excel("kaggle_headers.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsK.xlsx'
elif DB_or_dataset.lower() == 'kc':
    print("Using Kaggle Datasets Corrections")
    datasets_xlsx = pd.read_excel("kaggle_datasets_with_domain_and_match.xlsx")
    columns_xlsx = pd.read_excel("kaggle_headers_10k.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsKc.xlsx'
elif DB_or_dataset.lower() == 's':
    print("Using Sato Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("columns_sato_only.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSato.xlsx'
elif DB_or_dataset.lower() == 'sf':
    print("Using Sato Filtered Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("filtered_columns_sato_only.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSatoFiltered.xlsx'
elif DB_or_dataset.lower() == 'v':
    print("Using Viznet Filtered Datasets")
    datasets_xlsx = pd.read_excel("datasets_viznet.xlsx")
    columns_xlsx = pd.read_excel("filtered_columns_viznet_all.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsViznetFiltered.xlsx'
elif DB_or_dataset.lower() == 'kv':
    print("Using Kaggle Viznet Filtered Datasets")
    datasets_xlsx = pd.read_excel("kaggle_viznet_datasets.xlsx")
    columns_xlsx = pd.read_excel("filtered_kaggle_viznet_headers.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsKaggleViznetFiltered.xlsx'
elif DB_or_dataset.lower() == 'sem':
    print("Using SemTabTest 2024 terms")
    datasets_xlsx = pd.read_excel("SemTabTest2024Dataset.xlsx")
    columns_xlsx = pd.read_excel("SemTabTest2024.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSemTabTest2024.xlsx'
elif DB_or_dataset.lower() == 'sotab':
    print("Using Sotab metadata")
    datasets_xlsx = pd.read_excel("SotabShemasDataset.xlsx")
    columns_xlsx = pd.read_excel("SotabColumns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsSotab.xlsx'
elif DB_or_dataset.lower() == 't2dv2':
    print("Using t2dv2")
    datasets_xlsx = pd.read_excel("t2dv2Datasets.xlsx")
    columns_xlsx = pd.read_excel("t2dv2Columns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnst2dv2.xlsx'
elif DB_or_dataset.lower() == 'dbp':
    print("Using DbPedia metadata")
    datasets_xlsx = pd.read_excel("DbpediaDataset.xlsx")
    columns_xlsx = pd.read_excel("DbpediaMetadataColumns.xlsx")
    analysed_columns_file_path = 'AnalysedColumnsDbpediaMetadata.xlsx'
else:
    raise ValueError("Invalid input. Please enter 'd', 'dt', 'ds', 'k', 'kc', 's', 'sf', 'v' or 'kv'.")
# Out:
# kv
# Using Kaggle Viznet Filtered Datasets

# %%
columns_xlsx = columns_xlsx.rename(columns={'index': 'dataset_index'})

columns_xlsx.head()
# Out:
#   dataset_index                                    name       area  \
# 0          1001  student-habits-vs-academic-performance  Education
# 1          1001  student-habits-vs-academic-performance  Education
# 2          1001  student-habits-vs-academic-performance  Education
# 3          1001  student-habits-vs-academic-performance  Education
# 4          1001  student-habits-vs-academic-performance  Education
#
#             Original Column  ID
# 0           1.   student_id   1
# 1                  2.   age   2
# 2               3.   gender   3
# 3  4.   study_hours_per_day   4
# 4   5.   social_media_hours   5

# %%
def normalize_yn_in_original_column(
    df: pd.DataFrame,
    original_col: str = "Original Column",
    flag_col: str = "YN_Header_Flag"
) -> pd.DataFrame:
    """
    Detects 'y/n' or 'Y/N' (with optional spaces around the slash) in the
    ORIGINAL column header and replaces it with 'yes no', so that the existing
    pipeline can pick up 'yes' and infer FinalFormat = binary via formats_dictionary.

    Examples of replacements:
      'Smoker (Y/N)'       -> 'Smoker (yes no)'
      'y/n'                -> 'yes no'
      'Has siblings y / n' -> 'Has siblings yes no'
      'Flag Y/N value'     -> 'Flag yes no value'

    It also writes a boolean flag column to allow later inspection.
    """
    if original_col not in df.columns:
        raise KeyError(f"Column '{original_col}' not found in DataFrame")

    # Regex to find y/n patterns, case-insensitive, with optional spaces
    pattern = re.compile(r'\b[yY]\s*/\s*[nN]\b')

    # Flag rows where the pattern appears
    df[flag_col] = df[original_col].astype(str).str.contains(pattern.pattern, regex=True, na=False)

    # Replace y/n with 'yes no' in the original header
    def _replace_yn(text: str) -> str:
        if not isinstance(text, str):
            return text
        return pattern.sub(" yes no ", text)

    df[original_col] = df[original_col].astype(str).apply(_replace_yn)

    return df


# Example standalone usage
if __name__ == "__main__":
    test_df = pd.DataFrame({
        "Original Column": [
            "1. Smoker (Y/N)",
            "2. y/n",
            "3. Has siblings y / n?",
            "4. Approval (Yes/No)",   # already good, nothing happens
            "5. Random Flag"
        ]
    })

    test_df = normalize_yn_in_original_column(test_df)
    print(test_df)

    print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
#              Original Column  YN_Header_Flag
# 0       1. Smoker ( yes no )            True
# 1                2.  yes no             True
# 2  3. Has siblings  yes no ?            True
# 3       4. Approval (Yes/No)           False
# 4             5. Random Flag           False
# Last run on: 2025-11-17 19:32:35

# %% [markdown]
# Clean Columns

# %%
import pandas as pd
import re
from datetime import datetime

def clean_columns(df: pd.DataFrame) -> pd.DataFrame:
    # Always work on a copy to avoid side effects
    df = df.copy()

    # 0. Normalise Y/N into 'yes no' in the Original Column
    df = normalize_yn_in_original_column(df, original_col="Original Column", flag_col="YN_Header_Flag")

    # 1. Extract the ID from the column name 
    df['ID'] = df['Original Column'].str.extract(r'(\d+)\.')

    # 2. Extract the Column name up to the first colon, slash, or parenthesis
    df['Column'] = df['Original Column'].str.extract(r'\d+\.\s*([^/(:]+)')

    # 3. Extract everything after the first colon, slash, or parenthesis as the full description
    df['Description'] = df['Original Column'].str.extract(r'\d+\.\s*[^/(:]+\s*[:(/](.*)')[0]

    # 4. For cases where Description is None,
    #    extract the content within parentheses
    mask = df['Description'].isnull()
    df.loc[mask, 'Description'] = df.loc[mask, 'Original Column'].str.extract(r'\(([^)]+)\)')

    # 5. Trim spaces from all string columns
    for col in df.columns:
        if df[col].dtype == "object" and col != 'dataset_index':
            df[col] = df[col].str.strip()

    # 6. Replace empty strings with pd.NA  ← changed from None to pd.NA to avoid downcasting warning
    df = df.replace(r'^\s*$', pd.NA, regex=True)
    df = df.infer_objects(copy=False)
    
    # 7. Ensure Description is object dtype before applying .str.replace  ← added to avoid incompatible dtype warning
    df['Description'] = df['Description'].astype(object)

    # 8. Only apply .str.replace on non-null Description rows,
    #    converting to string first to avoid errors
    mask_desc = df['Description'].notnull()
    df.loc[mask_desc, 'Description'] = (
        df.loc[mask_desc, 'Description']
          .astype(str)
          .str.replace(r'\(', ' ', regex=True)
          .str.replace(r'\)', '', regex=True)
    )

    # 9. Reorder columns to ensure ID comes before Column
    columns_order = ['dataset_index', 'name', 'area', 'Original Column', 'ID', 'Column', 'Description']
    columns_order = [col for col in columns_order if col in df.columns]
    df = df[columns_order]

    return df

# Test the function with a sample DataFrame
if __name__ == "__main__":
    test_df = pd.DataFrame({
        'Original Column': [
            '14. num (the predicted attribute)',
            '1. lettr: capital letter (26 values from A to Z)',
            '2. x-box: horizontal position of the box (integer)',
            '1. sepal length in cm',
            '20. Foreign worker (qualitative)',
            '12. A12: Categorical with values: t, f',
            '55. capital_run_length_average (1 continuous real attribute): Average length of uninterrupted sequences of capital letters',
            '1. Class Name (party affiliation): democrat, republican',
            '1.Sex / nominal / -- / M, F, and I (infant)',
            '3.Cell Nucleus 1 - a) radius (mean of distances from center to points on the perimeter)',
            '14. win_loc (varchar(255))',
            '33. #',
            '14.   Rush_Y/A',
            '3.   PCOS (Y/N)'

        ],
        'dataset_index': ['SATO_000001'] * 14,
        'name': [None] * 14,
        'area': ['Sato-Viznet'] * 14
    })

print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
cleaned_df = normalize_yn_in_original_column(test_df)

cleaned_df = clean_columns(cleaned_df)
cleaned_df
# Out:
# Last run on: 2025-11-17 19:32:35
#    dataset_index  name         area  \
# 0    SATO_000001  None  Sato-Viznet
# 1    SATO_000001  None  Sato-Viznet
# 2    SATO_000001  None  Sato-Viznet
# 3    SATO_000001  None  Sato-Viznet
# 4    SATO_000001  None  Sato-Viznet
# 5    SATO_000001  None  Sato-Viznet
# 6    SATO_000001  None  Sato-Viznet
# 7    SATO_000001  None  Sato-Viznet
# 8    SATO_000001  None  Sato-Viznet
# 9    SATO_000001  None  Sato-Viznet
# 10   SATO_000001  None  Sato-Viznet
# 11   SATO_000001  None  Sato-Viznet
# 12   SATO_000001  None  Sato-Viznet
# 13   SATO_000001  None  Sato-Viznet
#
#                                       Original Column  ID  \
# 0                   14. num (the predicted attribute)  14
# 1    1. lettr: capital letter (26 values from A to Z)   1
# 2   2. x-box: horizontal position of the box (inte...   2
# 3                               1. sepal length in cm   1
# 4                    20. Foreign worker (qualitative)  20
# 5              12. A12: Categorical with values: t, f  12
# 6   55. capital_run_length_average (1 continuous r...  55
# 7   1. Class Name (party affiliation): democrat, r...   1
# 8         1.Sex / nominal / -- / M, F, and I (infant)   1
# 9   3.Cell Nucleus 1 - a) radius (mean of distance...   3
# 10                         14. win_loc (varchar(255))  14
# 11                                              33. #  33
# 12                                     14.   Rush_Y/A  14
# 13                               3.   PCOS ( yes no )   3
#
#                         Column  \
# 0                          num
# 1                        lettr
# 2                        x-box
# 3           sepal length in cm
# 4               Foreign worker
# 5                          A12
# 6   capital_run_length_average
# 7                   Class Name
# 8                          Sex
# 9   Cell Nucleus 1 - a) radius
# 10                     win_loc
# 11                           #
# 12                      Rush_Y
# 13                        PCOS
#
#                                           Description
# 0                             the predicted attribute
# 1               capital letter  26 values from A to Z
# 2             horizontal position of the box  integer
# 3                                                 NaN
# 4                                         qualitative
# 5                       Categorical with values: t, f
# 6   1 continuous real attribute: Average length of...
# 7             party affiliation: democrat, republican
# 8                  nominal / -- / M, F, and I  infant
# 9   mean of distances from center to points on the...
# 10                                        varchar 255
# 11                                                NaN
# 12                                                  A
# 13                                            yes no

# %% [markdown]
# Open formats and abreviations dictionaries

# %%
dictionary = {}

# Open the formats dictionary file and read line by line 
with open("formats_dictionary.txt", "r") as file:
    for line in file:
        # Remove the trailing newline and comma, then split the line into key and value at the colon
        key, value = line.rstrip(",\n").split(":")
    
        # Remove the quotes around the key and value
        key = key.strip("'").lower()
        value = value.strip("'")

        # Add the key-value pair to the dictionary
        dictionary[key] = value

target_words_dict = dictionary
description_words_dict = dictionary

# Load the abbreviations dictionary
abbreviations_dict = {}
with open("abbreviations_dictionary.txt", "r") as file:
    for line in file:
        abbr, full_form = line.strip().split(":")
        abbreviations_dict[abbr.strip().lower()] = full_form.strip()
        
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-11-17 19:32:35

# %% [markdown]
# Replace abbreviations

# %%
def replace_abbreviations(text, abbreviations_dict):
    """
    Tokenises `text` using the original regex and replaces tokens that appear
    in `abbreviations_dict`. In addition, it returns a log of which
    abbreviations were expanded.

    Returns:
        expanded_text, expansion_log

    - expanded_text: the text with abbreviations expanded
    - expansion_log: string like 'gp->games played|bmi->body mass index'
                     or '' (empty string) if nothing was expanded
    """
    if not isinstance(text, str):
        return text, ""

    tokens = re.findall(
        r'\b\w+(?:[-=]\w+)*\b'          # Words, with hyphens/equals (like 0-4, 1=NE)
        r'|[=]'                         # Standalone equal signs
        r'|[°º][CFK]'                   # °C, ºF, etc.
        r'|[°º\-]+'                     # Standalone degree/hyphens
        r'|[a-zA-Z]+/[a-zA-Z]+(?:[²³μµ]?)'   # mg/dL, kg/m², µg/m³, cm², etc.
        r'|\d+[²³]?'                    # 10², 5³ (numbers with superscripts)
        r'|%'                           # <- add this line to capture % as a token
        , text
    )
    #replaced_tokens = [abbreviations_dict.get(token.lower(), token) for token in tokens]
    #return " ".join(replaced_tokens)

    replaced_tokens = []
    used_mappings = []  # e.g. "bmi->body mass index" - we will log "abbr->expansion" here

    for token in tokens:
        key = token.lower()
        if key in abbreviations_dict:
            expansion = abbreviations_dict[key]
            replaced_tokens.append(expansion)
            used_mappings.append(f"{key}->{expansion}")
        else:
            replaced_tokens.append(token)

    # Remove duplicates but keep order
    seen = set()
    unique_used = []
    for m in used_mappings:
        if m not in seen:
            seen.add(m)
            unique_used.append(m)

    expansion_log = "|".join(unique_used)
    expanded_text = " ".join(replaced_tokens)

    return expanded_text, expansion_log

test_df = pd.DataFrame({
    "Original Column": [
        "1. chlorides (mg/dL)",                # plural with unit
        "2. chloride (mg/dL)",                 # singular with unit
        "3. Fuel_Price (USD/L)",               # phrase with underscore, unit
        "4. Tumor-size: 0-4, 5-9, 10-14",      # category ranges with hyphens
        "5. zone: 1=NE, 2=SE, 3=SW, 4=NW",     # code marker with equals
        "6. temperature (°C)",                 # temperature symbol
        "7. temperature (ºF)",                 # alternate degree symbol
        "8. Tdewpoint (from Chievres weather station), °C", # degree symbol at end
        "9. cm² measurement",                  # superscript unit
        "10. workclass",                       # compound word
        "11. landmass",                        # compound word
        "12. thickness (mm³)",                 # unit with superscript ³
        "13. concentration: 5mg/dL",           # value with unit
        "14. value: 10cm³",                    # value with unit
        "15. intensity: 5³, 10²",              # numeric with superscripts
        "16. 0-1 category",                    # hyphen, short
        "17. 1=Red, 2=Blue, 3=Green",          # equals for codes
        "18. percent (%)",                     # symbol in column
        "19. velocity (km/h)",                 # unit with slash
        "20. area: 10cm2, 10cm³",              # unit, no symbol and symbol
        "21. Alcohol (%)",                     # percent
        "22. BMI (kg/m²)",                     # slash, superscript
        "23. air_quality_index (AQI)",         # abbreviation as token
        "24. mean-pH",                         # hyphen in column name
    ]
})

test_df[["AbbrExpanded", "AbbrLog"]] = test_df["Original Column"].apply(
        lambda x: pd.Series(replace_abbreviations(str(x), abbreviations_dict),
                            index=["AbbrExpanded", "AbbrLog"])
    )

pd.set_option("display.max_colwidth", 200)
#print(test_df[["Original Column", "AbbrExpanded", "AbbrLog"]])

test_df[['Original Column', "AbbrExpanded", "AbbrLog"]]

# Apply the abbreviation/tokenizer function to every row
#test_df['AbbrExpanded'] = test_df['Original Column'].apply(lambda x: replace_abbreviations(str(x), abbreviations_dict))

# Display original and processed columns side by side for easy comparison
#pd.set_option('display.max_colwidth', 200)
#test_df[['Original Column', 'AbbrExpanded']]

#print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
#                                      Original Column  \
# 0                               1. chlorides (mg/dL)
# 1                                2. chloride (mg/dL)
# 2                              3. Fuel_Price (USD/L)
# 3                     4. Tumor-size: 0-4, 5-9, 10-14
# 4                    5. zone: 1=NE, 2=SE, 3=SW, 4=NW
# 5                                6. temperature (°C)
# 6                                7. temperature (ºF)
# 7   8. Tdewpoint (from Chievres weather station), °C
# 8                                 9. cm² measurement
# 9                                      10. workclass
# 10                                      11. landmass
# 11                               12. thickness (mm³)
# 12                         13. concentration: 5mg/dL
# 13                                  14. value: 10cm³
# 14                            15. intensity: 5³, 10²
# 15                                  16. 0-1 category
# 16                        17. 1=Red, 2=Blue, 3=Green
# 17                                   18. percent (%)
# 18                               19. velocity (km/h)
# 19                            20. area: 10cm2, 10cm³
# 20                                   21. Alcohol (%)
# 21                                   22. BMI (kg/m²)
# 22                       23. air_quality_index (AQI)
# 23                                       24. mean-pH
#
#                                     AbbrExpanded               AbbrLog
# 0                      1 chlorides milligrams dL        mg->milligrams
# 1                       2 chloride milligrams dL        mg->milligrams
# 2                        3 Fuel_Price USD losses             l->losses
# 3                     4 Tumor-size 0-4 5-9 10-14
# 4                     5 zone 1=NE 2=SE 3=SW 4=NW
# 5                               6 temperature °C
# 6                               7 temperature ºF
# 7   8 Tdewpoint from Chievres weather station °C
# 8                              9 cm² measurement
# 9                                   10 workclass
# 10                                   11 landmass
# 11                              12 thickness mm³
# 12                       13 concentration 5mg dL
# 13                                14 value 10cm³
# 14                           15 intensity 5³ 10²
# 15                               16 0-1 category
# 16                       17 1=Red 2=Blue 3=Green
# 17                                  18 percent %
# 18                           19 velocity km hits               h->hits
# 19                           20 area 10cm2 10cm³
# 20                                  21 Alcohol %
# 21                      22 body mass index kg m²  bmi->body mass index
# 22                      23 air_quality_index AQI
# 23                                    24 mean-pH

# %% [markdown]
# Split Camel Case

# %%
import re

def split_camel_case(s):
    if s.lower() == 'ph':
        return 'ph'
    # Split on separators
    tokens = re.split(r'[\s._\-]+', s)
    processed_tokens = []

    for token in tokens:
        if not token:
            continue
        # If all uppercase or digits, keep as is
        if token.isupper() or token.isdigit():
            processed_tokens.append(token.lower())
            continue
        # If all-uppercase+digits, keep as is
        if re.match(r'^[A-Z]{2,}\d+$', token):
            processed_tokens.append(token.lower())
            continue

        # Character-by-character scan
        words = []
        current = ''
        i = 0
        while i < len(token):
            c = token[i]
            if current == '':
                current = c
            elif (
                # lower->upper transition
                (current[-1].islower() and c.isupper()) or
                # digit->letter or letter->digit
                (current[-1].isdigit() and c.isalpha()) or
                (current[-1].isalpha() and c.isdigit())
            ):
                words.append(current)
                current = c
            else:
                current += c
            i += 1
        if current:
            words.append(current)

        # Now check if the last two or more are all caps: join them!
        if len(words) >= 2 and all(w.isupper() for w in words[-2:]) and len(''.join(words[-2:])) >= 2:
            # Join last all-cap runs
            n = len(words) - 1
            while n > 0 and words[n].isupper():
                n -= 1
            # All uppercase words from n+1 to end are the tail
            head = words[:n+1]
            tail = ''.join(words[n+1:])
            processed_tokens.extend([w.lower() for w in head if w])
            if tail:
                processed_tokens.append(tail.lower())
        else:
            processed_tokens.extend([w.lower() for w in words if w])

    return ' '.join(processed_tokens)

print(split_camel_case("reviews.sourceURLs"))   # reviews source urls
print(split_camel_case("prices.sourceURLs"))    # prices source urls
print(split_camel_case("sourceURLs"))           # source urls
print(split_camel_case("UrlLength"))            # url length
print(split_camel_case("nation_flag_url"))      # nation flag url
print(split_camel_case("URLs"))              # mean ph
print(split_camel_case("JSONFileURL"))          # json file url
print(split_camel_case("ODIDs"))                # odids
print(split_camel_case("ODID"))                # odid
# Out:
# reviews source urls
# prices source urls
# source urls
# url length
# nation flag url
# urls
# jsonfile url
# odids
# odid

# %%
columns_xlsx
# Out:
#        dataset_index  \
# 0               1001
# 1               1001
# 2               1001
# 3               1001
# 4               1001
# ...              ...
# 118634   SATO_079984
# 118635   SATO_079984
# 118636   SATO_079984
# 118637   SATO_079984
# 118638   SATO_079984
#
#                                                                                                                                              name  \
# 0                                                                                                          student-habits-vs-academic-performance
# 1                                                                                                          student-habits-vs-academic-performance
# 2                                                                                                          student-habits-vs-academic-performance
# 3                                                                                                          student-habits-vs-academic-performance
# 4                                                                                                          student-habits-vs-academic-performance
# ...                                                                                                                                           ...
# 118634  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118635  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118636  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118637  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118638  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
#
#                area           Original Column  ID
# 0         Education           1.   student_id   1
# 1         Education                  2.   age   2
# 2         Education               3.   gender   3
# 3         Education  4.   study_hours_per_day   4
# 4         Education   5.   social_media_hours   5
# ...             ...                       ...  ..
# 118634  Sato-Viznet                 2.   Name   2
# 118635  Sato-Viznet             3.   Friendly   3
# 118636  Sato-Viznet              4.   Honored   4
# 118637  Sato-Viznet              5.   Revered   5
# 118638  Sato-Viznet              6.   Exalted   6
#
# [118639 rows x 5 columns]

# %%
cleaned_columns_df = clean_columns(columns_xlsx.copy())
cleaned_columns_df
# Out:
#        dataset_index  \
# 0               1001
# 1               1001
# 2               1001
# 3               1001
# 4               1001
# ...              ...
# 118634   SATO_079984
# 118635   SATO_079984
# 118636   SATO_079984
# 118637   SATO_079984
# 118638   SATO_079984
#
#                                                                                                                                              name  \
# 0                                                                                                          student-habits-vs-academic-performance
# 1                                                                                                          student-habits-vs-academic-performance
# 2                                                                                                          student-habits-vs-academic-performance
# 3                                                                                                          student-habits-vs-academic-performance
# 4                                                                                                          student-habits-vs-academic-performance
# ...                                                                                                                                           ...
# 118634  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118635  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118636  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118637  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118638  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
#
#                area           Original Column ID               Column  \
# 0         Education           1.   student_id  1           student_id
# 1         Education                  2.   age  2                  age
# 2         Education               3.   gender  3               gender
# 3         Education  4.   study_hours_per_day  4  study_hours_per_day
# 4         Education   5.   social_media_hours  5   social_media_hours
# ...             ...                       ... ..                  ...
# 118634  Sato-Viznet                 2.   Name  2                 Name
# 118635  Sato-Viznet             3.   Friendly  3             Friendly
# 118636  Sato-Viznet              4.   Honored  4              Honored
# 118637  Sato-Viznet              5.   Revered  5              Revered
# 118638  Sato-Viznet              6.   Exalted  6              Exalted
#
#        Description
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 118634         NaN
# 118635         NaN
# 118636         NaN
# 118637         NaN
# 118638         NaN
#
# [118639 rows x 7 columns]

# %% [markdown]
# Preprocess Columns

# %%
def preprocess_columns(df):
        
    """
    - Creates CleanedColumn from Column (split_camel_case + cleaning).
    - Applies replace_abbreviations to both CleanedColumn and Description.
    - Stores mapping logs in:
        df['abbrev_clean']  (from CleanedColumn)
        df['abbrev_desc']   (from Description)
    """

    # Only convert "Column" to string type for non-null values and then to lowercase to create "CleanedColumn"

    
    mask_col = df['Column'].notna()

    df.loc[mask_col, 'Column'] = df.loc[mask_col, 'Column'].str.replace('#', 'number', regex=False)
    df.loc[mask_col, 'Column'] = df.loc[mask_col, 'Column'].str.replace('$', 'dollar', regex=False)

    df.loc[mask_col, 'CleanedColumn'] = df.loc[mask_col, 'Column'].astype(str).apply(split_camel_case)
    
    # Remove '-' and '_' characters only for non-null values
    mask_clean = df['CleanedColumn'].notna()
    df.loc[mask_clean, 'CleanedColumn'] = df.loc[mask_clean, 'CleanedColumn'].str.replace('[-_]', ' ', regex=True)
    
    # Ensure log columns exist
    if 'abbrev_clean' not in df.columns:
        df['abbrev_clean'] = pd.NA
    if 'abbrev_desc' not in df.columns:
        df['abbrev_desc'] = pd.NA

    if mask_clean.any():
        expanded_clean = df.loc[mask_clean, 'CleanedColumn'].apply(
            lambda x: pd.Series(
                replace_abbreviations(x, abbreviations_dict),
                index=['CleanedColumn', 'abbrev_clean_tmp']
            )
        )
        df.loc[mask_clean, 'CleanedColumn'] = expanded_clean['CleanedColumn']
        df.loc[mask_clean, 'abbrev_clean'] = expanded_clean['abbrev_clean_tmp']

    mask_desc = df['Description'].notna()
    if mask_desc.any():
        expanded_desc = df.loc[mask_desc, 'Description'].apply(
            lambda x: pd.Series(
                replace_abbreviations(x, abbreviations_dict),
                index=['Description', 'abbrev_desc_tmp']
            )
        )
        df.loc[mask_desc, 'Description'] = expanded_desc['Description']
        df.loc[mask_desc, 'abbrev_desc'] = expanded_desc['abbrev_desc_tmp']     

    return df

# Clean the columns

cleaned_columns_df = clean_columns(columns_xlsx.copy())

# Preprocess the column names
preprocessed_columns_df = preprocess_columns(cleaned_columns_df)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

preprocessed_columns_df
# Out:
# Last run on: 2025-11-17 19:32:52
#        dataset_index  \
# 0               1001
# 1               1001
# 2               1001
# 3               1001
# 4               1001
# ...              ...
# 118634   SATO_079984
# 118635   SATO_079984
# 118636   SATO_079984
# 118637   SATO_079984
# 118638   SATO_079984
#
#                                                                                                                                              name  \
# 0                                                                                                          student-habits-vs-academic-performance
# 1                                                                                                          student-habits-vs-academic-performance
# 2                                                                                                          student-habits-vs-academic-performance
# 3                                                                                                          student-habits-vs-academic-performance
# 4                                                                                                          student-habits-vs-academic-performance
# ...                                                                                                                                           ...
# 118634  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118635  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118636  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118637  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
# 118638  0_1438042987171.38;warc;CC-MAIN-20150728002307-00339-ip-10-236-191-2.ec2.internal.json.gz_716-Southsea Freebooters - WoW_HKCEY7NCAYUBBODC
#
#                area           Original Column ID               Column  \
# 0         Education           1.   student_id  1           student_id
# 1         Education                  2.   age  2                  age
# 2         Education               3.   gender  3               gender
# 3         Education  4.   study_hours_per_day  4  study_hours_per_day
# 4         Education   5.   social_media_hours  5   social_media_hours
# ...             ...                       ... ..                  ...
# 118634  Sato-Viznet                 2.   Name  2                 Name
# 118635  Sato-Viznet             3.   Friendly  3             Friendly
# 118636  Sato-Viznet              4.   Honored  4              Honored
# 118637  Sato-Viznet              5.   Revered  5              Revered
# 118638  Sato-Viznet              6.   Exalted  6              Exalted
#
#        Description        CleanedColumn abbrev_clean abbrev_desc
# 0              NaN           student id                     <NA>
# 1              NaN                  age                     <NA>
# 2              NaN               gender                     <NA>
# 3              NaN  study hours per day                     <NA>
# 4              NaN   social media hours                     <NA>
# ...            ...                  ...          ...         ...
# 118634         NaN                 name                     <NA>
# 118635         NaN             friendly                     <NA>
# 118636         NaN              honored                     <NA>
# 118637         NaN              revered                     <NA>
# 118638         NaN              exalted                     <NA>
#
# [118639 rows x 10 columns]

# %% [markdown]
# KG Matching

# %%
import pandas as pd
import difflib
import numpy as np
from gensim.models.fasttext import load_facebook_vectors

# Load DBpedia and Schema.org ontology terms from your provided files
dbpedia_terms_df = pd.read_excel('dbpedia.xlsx')
dbpedia_labels = dbpedia_terms_df['cleaned_label'].astype(str).str.lower().tolist()
dbpedia_ids = dbpedia_terms_df['id'].astype(str).tolist()
dbpedia_label_to_id = dict(zip(dbpedia_labels, dbpedia_ids))

schema_terms_df = pd.read_excel('schema.xlsx')
schema_labels = schema_terms_df['cleaned_label'].astype(str).str.lower().tolist()
schema_ids = schema_terms_df['id'].astype(str).tolist()
schema_label_to_id = dict(zip(schema_labels, schema_ids))

print("Loaded DBpedia labels:", dbpedia_labels[:5], "...")
print("DBpedia label to id (sample):", {k: dbpedia_label_to_id[k] for k in dbpedia_labels[:3]})

print("Loaded Schema.org labels:", schema_labels[:5], "...")
print("Schema.org label to id (sample):", {k: schema_label_to_id[k] for k in schema_labels[:3]})

def syntactic_match(header, labels_list, label_to_id, threshold=0.9):
    header = header.strip().lower()
    if header in label_to_id:
        return label_to_id[header]
    matches = difflib.get_close_matches(header, labels_list, n=1, cutoff=threshold)
    if matches:
        return label_to_id[matches[0]]
    return None

# Load Gensim FastText model
fasttext_model = load_facebook_vectors('cc.en.300.bin')  # Update with the path to your file

print("Gensim FastText model loaded. Dimension:", fasttext_model.vector_size)

def get_embedding(text):
    words = text.split()
    vectors = [fasttext_model[w] for w in words if w in fasttext_model]
    if not vectors:
        return np.zeros(fasttext_model.vector_size)
    return np.mean(vectors, axis=0)

print("Embedding for 'birth date':", get_embedding("birth date")[:5])  # show first 5 numbers for brevity

def semantic_match(header, labels_list, label_to_id, embeddings_dict, similarity_threshold=0.9):
    header_emb = get_embedding(header)
    best_sim = -1
    best_label = None
    for label, emb in embeddings_dict.items():
        sim = np.dot(header_emb, emb) / (np.linalg.norm(header_emb) * np.linalg.norm(emb) + 1e-8)
        if sim > best_sim:
            best_sim = sim
            best_label = label
    if best_sim >= similarity_threshold:
        return label_to_id[best_label], best_sim
    return None, best_sim

# Precompute embeddings for ontology terms (can take a minute for large lists)
dbpedia_embeddings = {label: get_embedding(label) for label in dbpedia_labels}
schema_embeddings = {label: get_embedding(label) for label in schema_labels}

print("Sample DBpedia label embedding shape:", dbpedia_embeddings[dbpedia_labels[0]].shape)
print("First 5 dims of first embedding:", dbpedia_embeddings[dbpedia_labels[0]][:5])

# Try with some typical headers
test_headers = ['birth date', 'organization', 'assets', 'zip code', 'unknownfield']

for th in test_headers:
    result = syntactic_match(th, dbpedia_labels, dbpedia_label_to_id)
    print(f"Syntactic match (DBpedia) for '{th}':", result)
    result = syntactic_match(th, schema_labels, schema_label_to_id)
    print(f"Syntactic match (Schema.org) for '{th}':", result)

# Pick a header that may not match exactly but should semantically (abbreviations etc.)
sem_headers = ['assets', 'amt', 'org unit', 'unknownfield']

for sh in sem_headers:
    result = semantic_match(sh, dbpedia_labels, dbpedia_label_to_id, dbpedia_embeddings)
    print(f"Semantic match (DBpedia) for '{sh}':", result)
    result = semantic_match(sh, schema_labels, schema_label_to_id, schema_embeddings)
    print(f"Semantic match (Schema.org) for '{sh}':", result)
# Out:
# Loaded DBpedia labels: ['a side', 'abbeychurch blessing', 'abbeychurch blessing charge', 'abbreviation', 'able to grind'] ...
# DBpedia label to id (sample): {'a side': 'http://dbpedia.org/ontology/aSide', 'abbeychurch blessing': 'http://dbpedia.org/ontology/abbeychurchBlessing', 'abbeychurch blessing charge': 'http://dbpedia.org/ontology/abbeychurchBlessingCharge'}
# Loaded Schema.org labels: ['3 d model', 'abdomen', 'about', 'about page', 'abridged'] ...
# Schema.org label to id (sample): {'3 d model': 'https://schema.org/3DModel', 'abdomen': 'https://schema.org/Abdomen', 'about': 'https://schema.org/about'}
# Gensim FastText model loaded. Dimension: 300
# Embedding for 'birth date': [ 0.00283275  0.0443643  -0.06757186  0.06091432  0.00819952]
# Sample DBpedia label embedding shape: (300,)
# First 5 dims of first embedding: [ 0.01555624 -0.24466786  0.00117554 -0.002059   -0.03555111]
# Syntactic match (DBpedia) for 'birth date': http://dbpedia.org/ontology/birthDate
# Syntactic match (Schema.org) for 'birth date': https://schema.org/birthDate
# Syntactic match (DBpedia) for 'organization': http://dbpedia.org/ontology/Organization
# Syntactic match (Schema.org) for 'organization': https://schema.org/Organization
# Syntactic match (DBpedia) for 'assets': http://dbpedia.org/ontology/assets
# Syntactic match (Schema.org) for 'assets': None
# Syntactic match (DBpedia) for 'zip code': http://dbpedia.org/ontology/zipCode
# Syntactic match (Schema.org) for 'zip code': None
# Syntactic match (DBpedia) for 'unknownfield': None
# Syntactic match (Schema.org) for 'unknownfield': None
# Semantic match (DBpedia) for 'assets': ('http://dbpedia.org/ontology/assets', 1.0000000542607073)
# Semantic match (Schema.org) for 'assets': (None, 0.4719898244507163)
# Semantic match (DBpedia) for 'amt': (None, 0.41080459931294044)
# Semantic match (Schema.org) for 'amt': (None, 0.5676016132668965)
# Semantic match (DBpedia) for 'org unit': (None, 0.47278003880190883)
# Semantic match (Schema.org) for 'org unit': (None, 0.4896823450750818)
# Semantic match (DBpedia) for 'unknownfield': (None, 0.4986249117228689)
# Semantic match (Schema.org) for 'unknownfield': (None, 0.4192307349239801)

# %% [markdown]
# Apply analysis

# %%
import pandas as pd
import re

def match_with_plural(token, dictionary):
    # Attempt direct match first
    if token in dictionary:
        return dictionary[token]
    # Check for 'ies' -> 'y' (families -> family)
    if token.endswith('ies') and len(token) > 3:
        singular = token[:-3] + 'y'
        if singular in dictionary:
            return dictionary[singular]
    # Check for 'es' -> '' (e.g., classes -> class)
    if token.endswith('es') and len(token) > 2:
        singular = token[:-2]
        if singular in dictionary:
            return dictionary[singular]
    # Check for 's' -> '' (e.g., chlorides -> chloride)
    if token.endswith('s') and len(token) > 2:
        singular = token[:-1]
        if singular in dictionary:
            return dictionary[singular]
    return None

def apply_analysis(df, target_words_dict, description_words_dict, abbreviations_dict, all_datasets_info):

    def get_special_name_format(table_name, column_name):
        special_cases = {
            'city': 'city',
            'country': 'country',
            'state': 'state',
            'province': 'state'  # province is treated as state
        }
        
        if DB_or_dataset.lower() == 'd':
            # For datasets, table_name is a number, so we don't check it
            if column_name.lower() == 'name':
                return 'name', target_words_dict['name']
        else:
            # For database tables, check if any special case is in the table name
            table_name_str = str(table_name).lower()
            for case, format_type in special_cases.items():
                if case in table_name_str and column_name.lower() == 'name':
                    return f"{format_type}_name", target_words_dict[format_type]
        
        return 'name', target_words_dict['name']
    
    # main code 
    # Check if PK/FK information is available
    has_pk_fk_info = 'primary_key' in all_datasets_info.columns and 'foreign_keys' in all_datasets_info.columns

    # Get primary and foreign keys for each table
    pk_fk_dict = {}
    if has_pk_fk_info:
        for _, row in all_datasets_info.iterrows():
            table_name = row['index']
            pk = row['primary_key'] if pd.notna(row['primary_key']) else None
            fks = row['foreign_keys'].split(', ') if pd.notna(row['foreign_keys']) else []
            fk_columns = [fk.split(' -> ')[0] for fk in fks]
            pk_fk_dict[table_name] = {'pk': pk, 'fks': fk_columns} 

    # 'formats_ordered_list' is a list of dictionary keys in the order they appear in 'formats_dictionary'
    formats_ordered_list = list(target_words_dict.keys())

    # Initialize new columns
    df['ColumnKeyword'] = None
    df['ColumnFormat'] = None
    df['DescriptionKeyword'] = None
    df['DescriptionFormat'] = None
    count = 0
   
    # Apply target words analysis
    for i, row in df.iterrows():
        count += 1
        if count % 1000 == 0:
            print(f"✅ Processed {count} rows...")

        std_col_name = row['CleanedColumn']
        col_name = row['Column']
        table_name = row['dataset_index']

        # Skip if 'CleanedColumn' is missing
        if pd.isnull(std_col_name):
            continue

        # Split camel case
        std_col_name = split_camel_case(std_col_name)

        # Check if the column is a primary key or foreign key
        if table_name in pk_fk_dict:
            if col_name == pk_fk_dict[table_name]['pk'] or col_name in pk_fk_dict[table_name]['fks']:
                df.at[i, 'ColumnKeyword'] = 'id'
                df.at[i, 'ColumnFormat'] = 'IDcolumn'
                continue

        found = False

        # Iterate through each word based on the order in 'formats_ordered_list'
        for word in formats_ordered_list:
            analysis = target_words_dict[word.lower()]
            # Special handling for 'name'
            if word == 'name':
                keyword, format_type = get_special_name_format(table_name, col_name)
                if keyword != 'name':
                    df.at[i, 'ColumnKeyword'] = keyword
                    df.at[i, 'ColumnFormat'] = format_type
                    found = True
                    break
                pattern = rf'({word})(?![\\w-])'
            # Special handling for uppercase 'ID' at the end of a column name
            elif word == 'id' and col_name.endswith('ID'):
                df.at[i, 'ColumnKeyword'] = 'id'
                df.at[i, 'ColumnFormat'] = target_words_dict.get('id', 'ID column')
                found = True
                break
            else:
                # General matching for other terms
                pattern = rf'\b{word}\b'

            # Search for the pattern in the CleanedColumn
            if re.search(pattern, std_col_name, re.IGNORECASE):
                df.at[i, 'ColumnKeyword'] = word
                df.at[i, 'ColumnFormat'] = analysis
                found = True
                break

        # If no match found, replace abbreviations and try again
        if not found:
            replaced_text, abbr_log = replace_abbreviations(std_col_name, abbreviations_dict)
            if abbr_log:
                df.at[i, 'abbrev_clean_analysis'] = abbr_log
                
            for word in formats_ordered_list:
                pattern = rf'\b{word}\b'
                if re.search(pattern, replaced_text, re.IGNORECASE):
                    df.at[i, 'ColumnKeyword'] = word
                    df.at[i, 'ColumnFormat'] = target_words_dict[word.lower()]
                    found = True
                    break


        # If still no match, check tokens only
        if not found:
            tokens = re.findall(r'\b\w+\b|%', row['CleanedColumn'].lower())
            for token in tokens:
                expanded_token = abbreviations_dict.get(token.lower(), None)
                # First check plural support for expanded_token
                if expanded_token:
                    match = match_with_plural(expanded_token, target_words_dict)
                    if match:
                        df.at[i, 'ColumnKeyword'] = expanded_token
                        df.at[i, 'ColumnFormat'] = match
                        found = True
                        break
                # Then check plural support for the token itself
                match = match_with_plural(token, target_words_dict)
                if match:
                    df.at[i, 'ColumnKeyword'] = token
                    df.at[i, 'ColumnFormat'] = match
                    found = True
                    break

        # -- PRIORITIZE percentage if % present in CleanedColumn tokens --
        tokens = re.findall(r'\b\w+\b|%', row['CleanedColumn'].lower())
        if '%' in tokens and '%' in target_words_dict:
            df.at[i, 'ColumnKeyword'] = '%'
            df.at[i, 'ColumnFormat'] = target_words_dict['%']

    count = 0
    # Apply description words analysis
    for i, row in df.iterrows():
        count += 1
        if count % 1000 == 0:
            print(f"✅ Processed {count} rows...")
        # Skip if 'Description' is missing
        if pd.isnull(row['Description']):
            continue
        for word, analysis in description_words_dict.items():
            if word in ['is', 'has']:
                pattern = r'^\s*' + re.escape(word) + r'\b'
                if re.search(pattern, row['Description'], re.IGNORECASE):
                    df.at[i, 'DescriptionKeyword'] = word
                    df.at[i, 'DescriptionFormat'] = analysis
                    break
            else:
                if re.search(rf'\b{re.escape(word)}\b', row['Description'], re.IGNORECASE):
                    df.at[i, 'DescriptionKeyword'] = word
                    df.at[i, 'DescriptionFormat'] = analysis
                    break
                elif not word.isalnum():
                    if word.lower() in row['Description'].lower():
                        df.at[i, 'DescriptionKeyword'] = word
                        df.at[i, 'DescriptionFormat'] = analysis
                        break

    return df

# Apply this function to the dataframe
analysed_columns_df = apply_analysis(preprocessed_columns_df.copy(), target_words_dict, description_words_dict, abbreviations_dict, datasets_xlsx)


def match_with_ontology(
    header, labels_list, label_to_id, embeddings_dict,
    syntactic_thresh=0.9, semantic_thresh=0.7, column_keyword=None
):
    header_lc = header.lower().strip()

    # 1. Syntactic (exact) match
    match_id = syntactic_match(header_lc, labels_list, label_to_id, threshold=syntactic_thresh)
    if match_id:
        return match_id, 1.0

    # 2. Substring preference (force this to happen BEFORE semantic!)
    substr_matches = [label for label in labels_list if label in header_lc and len(label) >= 4]
    if substr_matches:
        substr_matches = sorted(
            substr_matches,
            key=lambda x: (len(x.split()), len(x)),  # more words, then longer
            reverse=True
        )
        best_label = substr_matches[0]
        #print(f"[Substring wins] '{best_label}' in '{header}'")
        return label_to_id[best_label], 1.0

    # 3. Semantic match
    match_id, sim_score = semantic_match(header_lc, labels_list, label_to_id, embeddings_dict, similarity_threshold=semantic_thresh)
    if match_id:
        return match_id, sim_score

    # 4. ColumnKeyword
    if column_keyword:
        ck = column_keyword.lower().strip()
        match_id = syntactic_match(ck, labels_list, label_to_id, threshold=syntactic_thresh)
        if match_id:
            return match_id, 1.0
        match_id, sim_score_ck = semantic_match(ck, labels_list, label_to_id, embeddings_dict, similarity_threshold=semantic_thresh)
        if match_id:
            return match_id, sim_score_ck

    return "Nil", 0.0


def annotate_all_kgs(df, syntactic_thresh=0.9, semantic_thresh=0.75):
    def kg_annotate_row(row, labels_list, label_to_id, embeddings_dict):
        return match_with_ontology(
            str(row['CleanedColumn']),
            labels_list, label_to_id, embeddings_dict,
            syntactic_thresh, semantic_thresh,
            column_keyword=row.get('ColumnKeyword', None)
        )

    db_results = df.apply(
        lambda row: kg_annotate_row(row, dbpedia_labels, dbpedia_label_to_id, dbpedia_embeddings),
        axis=1
    )
    df['DBpediaType'] = [r[0] for r in db_results]
    df['DBpediaScore'] = [r[1] for r in db_results]

    schema_results = df.apply(
        lambda row: kg_annotate_row(row, schema_labels, schema_label_to_id, schema_embeddings),
        axis=1
    )
    df['SchemaOrgType'] = [r[0] for r in schema_results]
    df['SchemaScore'] = [r[1] for r in schema_results]

    return df


analysed_columns_df['ColumnDescCombined'] = (
    analysed_columns_df['CleanedColumn'].fillna('').astype(str) + ' ' +
    analysed_columns_df['Description'].fillna('').astype(str)
)

analysed_columns_df = annotate_all_kgs(analysed_columns_df, syntactic_thresh=1.0)

# Preview results
ac = analysed_columns_df[['CleanedColumn', 'Description', 'DBpediaType', 'DBpediaScore', 'SchemaOrgType', 'SchemaScore']].head(60)

print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

ac
# Out:
# ✅ Processed 1000 rows...
# ✅ Processed 2000 rows...
# ✅ Processed 3000 rows...
# ✅ Processed 4000 rows...
# ✅ Processed 5000 rows...
# ✅ Processed 6000 rows...
# ✅ Processed 7000 rows...
# ✅ Processed 8000 rows...
# ✅ Processed 9000 rows...
# ✅ Processed 10000 rows...
# ✅ Processed 11000 rows...
# ✅ Processed 12000 rows...
# ✅ Processed 13000 rows...
# ✅ Processed 14000 rows...
# ✅ Processed 15000 rows...
# ✅ Processed 16000 rows...
# ✅ Processed 17000 rows...
# ✅ Processed 18000 rows...
# ✅ Processed 19000 rows...
# ✅ Processed 20000 rows...
# ✅ Processed 21000 rows...
# ✅ Processed 22000 rows...
# ✅ Processed 23000 rows...
# ✅ Processed 24000 rows...
# ✅ Processed 25000 rows...
# ✅ Processed 26000 rows...
# ✅ Processed 27000 rows...
# ✅ Processed 28000 rows...
# ✅ Processed 29000 rows...
# ✅ Processed 30000 rows...
# ✅ Processed 31000 rows...
# ✅ Processed 32000 rows...
# ✅ Processed 33000 rows...
# ✅ Processed 34000 rows...
# ✅ Processed 35000 rows...
# ✅ Processed 36000 rows...
# ✅ Processed 37000 rows...
# ✅ Processed 38000 rows...
# ✅ Processed 39000 rows...
# ✅ Processed 40000 rows...
# ✅ Processed 41000 rows...
# ✅ Processed 42000 rows...
# ✅ Processed 43000 rows...
# ✅ Processed 44000 rows...
# ✅ Processed 45000 rows...
# ✅ Processed 46000 rows...
# ✅ Processed 47000 rows...
# ✅ Processed 48000 rows...
# ✅ Processed 49000 rows...
# ✅ Processed 50000 rows...
# ✅ Processed 51000 rows...
# ✅ Processed 52000 rows...
# ✅ Processed 53000 rows...
# ✅ Processed 54000 rows...
# ✅ Processed 55000 rows...
# ✅ Processed 56000 rows...
# ✅ Processed 57000 rows...
# ✅ Processed 58000 rows...
# ✅ Processed 59000 rows...
# ✅ Processed 60000 rows...
# ✅ Processed 61000 rows...
# ✅ Processed 62000 rows...
# ✅ Processed 63000 rows...
# ✅ Processed 64000 rows...
# ✅ Processed 65000 rows...
# ✅ Processed 66000 rows...
# ✅ Processed 67000 rows...
# ✅ Processed 68000 rows...
# ✅ Processed 69000 rows...
# ✅ Processed 70000 rows...
# ✅ Processed 71000 rows...
# ✅ Processed 72000 rows...
# ✅ Processed 73000 rows...
# ✅ Processed 74000 rows...
# ✅ Processed 75000 rows...
# ✅ Processed 76000 rows...
# ✅ Processed 77000 rows...
# ✅ Processed 78000 rows...
# ✅ Processed 79000 rows...
# ✅ Processed 80000 rows...
# ✅ Processed 81000 rows...
# ✅ Processed 82000 rows...
# ✅ Processed 83000 rows...
# ✅ Processed 84000 rows...
# ✅ Processed 85000 rows...
# ✅ Processed 86000 rows...
# ✅ Processed 87000 rows...
# ✅ Processed 88000 rows...
# ✅ Processed 89000 rows...
# ✅ Processed 90000 rows...
# ✅ Processed 91000 rows...
# ✅ Processed 92000 rows...
# ✅ Processed 93000 rows...
# ✅ Processed 94000 rows...
# ✅ Processed 95000 rows...
# ✅ Processed 96000 rows...
# ✅ Processed 97000 rows...
# ✅ Processed 98000 rows...
# ✅ Processed 99000 rows...
# ✅ Processed 100000 rows...
# ✅ Processed 101000 rows...
# ✅ Processed 102000 rows...
# ✅ Processed 103000 rows...
# ✅ Processed 104000 rows...
# ✅ Processed 105000 rows...
# ✅ Processed 106000 rows...
# ✅ Processed 107000 rows...
# ✅ Processed 108000 rows...
# ✅ Processed 109000 rows...
# ✅ Processed 110000 rows...
# ✅ Processed 111000 rows...
# ✅ Processed 112000 rows...
# ✅ Processed 113000 rows...
# ✅ Processed 114000 rows...
# ✅ Processed 115000 rows...
# ✅ Processed 116000 rows...
# ✅ Processed 117000 rows...
# ✅ Processed 118000 rows...
# ✅ Processed 1000 rows...
# ✅ Processed 2000 rows...
# ✅ Processed 3000 rows...
# ✅ Processed 4000 rows...
# ✅ Processed 5000 rows...
# ✅ Processed 6000 rows...
# ✅ Processed 7000 rows...
# ✅ Processed 8000 rows...
# ✅ Processed 9000 rows...
# ✅ Processed 10000 rows...
# ✅ Processed 11000 rows...
# ✅ Processed 12000 rows...
# ✅ Processed 13000 rows...
# ✅ Processed 14000 rows...
# ✅ Processed 15000 rows...
# ✅ Processed 16000 rows...
# ✅ Processed 17000 rows...
# ✅ Processed 18000 rows...
# ✅ Processed 19000 rows...
# ✅ Processed 20000 rows...
# ✅ Processed 21000 rows...
# ✅ Processed 22000 rows...
# ✅ Processed 23000 rows...
# ✅ Processed 24000 rows...
# ✅ Processed 25000 rows...
# ✅ Processed 26000 rows...
# ✅ Processed 27000 rows...
# ✅ Processed 28000 rows...
# ✅ Processed 29000 rows...
# ✅ Processed 30000 rows...
# ✅ Processed 31000 rows...
# ✅ Processed 32000 rows...
# ✅ Processed 33000 rows...
# ✅ Processed 34000 rows...
# ✅ Processed 35000 rows...
# ✅ Processed 36000 rows...
# ✅ Processed 37000 rows...
# ✅ Processed 38000 rows...
# ✅ Processed 39000 rows...
# ✅ Processed 40000 rows...
# ✅ Processed 41000 rows...
# ✅ Processed 42000 rows...
# ✅ Processed 43000 rows...
# ✅ Processed 44000 rows...
# ✅ Processed 45000 rows...
# ✅ Processed 46000 rows...
# ✅ Processed 47000 rows...
# ✅ Processed 48000 rows...
# ✅ Processed 49000 rows...
# ✅ Processed 50000 rows...
# ✅ Processed 51000 rows...
# ✅ Processed 52000 rows...
# ✅ Processed 53000 rows...
# ✅ Processed 54000 rows...
# ✅ Processed 55000 rows...
# ✅ Processed 56000 rows...
# ✅ Processed 57000 rows...
# ✅ Processed 58000 rows...
# ✅ Processed 59000 rows...
# ✅ Processed 60000 rows...
# ✅ Processed 61000 rows...
# ✅ Processed 62000 rows...
# ✅ Processed 63000 rows...
# ✅ Processed 64000 rows...
# ✅ Processed 65000 rows...
# ✅ Processed 66000 rows...
# ✅ Processed 67000 rows...
# ✅ Processed 68000 rows...
# ✅ Processed 69000 rows...
# ✅ Processed 70000 rows...
# ✅ Processed 71000 rows...
# ✅ Processed 72000 rows...
# ✅ Processed 73000 rows...
# ✅ Processed 74000 rows...
# ✅ Processed 75000 rows...
# ✅ Processed 76000 rows...
# ✅ Processed 77000 rows...
# ✅ Processed 78000 rows...
# ✅ Processed 79000 rows...
# ✅ Processed 80000 rows...
# ✅ Processed 81000 rows...
# ✅ Processed 82000 rows...
# ✅ Processed 83000 rows...
# ✅ Processed 84000 rows...
# ✅ Processed 85000 rows...
# ✅ Processed 86000 rows...
# ✅ Processed 87000 rows...
# ✅ Processed 88000 rows...
# ✅ Processed 89000 rows...
# ✅ Processed 90000 rows...
# ✅ Processed 91000 rows...
# ✅ Processed 92000 rows...
# ✅ Processed 93000 rows...
# ✅ Processed 94000 rows...
# ✅ Processed 95000 rows...
# ✅ Processed 96000 rows...
# ✅ Processed 97000 rows...
# ✅ Processed 98000 rows...
# ✅ Processed 99000 rows...
# ✅ Processed 100000 rows...
# ✅ Processed 101000 rows...
# ✅ Processed 102000 rows...
# ✅ Processed 103000 rows...
# ✅ Processed 104000 rows...
# ✅ Processed 105000 rows...
# ✅ Processed 106000 rows...
# ✅ Processed 107000 rows...
# ✅ Processed 108000 rows...
# ✅ Processed 109000 rows...
# ✅ Processed 110000 rows...
# ✅ Processed 111000 rows...
# ✅ Processed 112000 rows...
# ✅ Processed 113000 rows...
# ✅ Processed 114000 rows...
# ✅ Processed 115000 rows...
# ✅ Processed 116000 rows...
# ✅ Processed 117000 rows...
# ✅ Processed 118000 rows...
# [Substring wins] 'student' in 'student id'
# [Substring wins] 'media' in 'social media hours'
# [Substring wins] 'part' in 'part time job'
# [Substring wins] 'percentage' in 'attendance percentage'
# [Substring wins] 'frequency' in 'exercise frequency'
# [Substring wins] 'education' in 'parental education level'
# [Substring wins] 'rating' in 'mental health rating'
# [Substring wins] 'part' in 'extracurricular participation'
# [Substring wins] 'score' in 'exam score'
# [Substring wins] 'time' in 'daily time spent'
# [Substring wins] 'date' in 'date joined'
# [Substring wins] 'time' in 'daily screen time hours'
# [Substring wins] 'media' in 'social media hours'
# [Substring wins] 'related' in 'work related hours'
# [Substring wins] 'duration' in 'sleep duration hours'
# [Substring wins] 'rating' in 'mood rating'
# [Substring wins] 'activity' in 'physical activity hours per week'
# [Substring wins] 'location' in 'location type'
# [Substring wins] 'score' in 'mental health score'
# [Substring wins] 'uses' in 'uses wellness apps'
# [Substring wins] 'mill' in 'caffeine intake milligrams per day'
# [Substring wins] 'score' in 'weekly anxiety score'
# [Substring wins] 'score' in 'weekly depression score'
# [Substring wins] 'duration' in 'duration years'
# [Substring wins] 'tuition' in 'tuition usd'
# [Substring wins] 'cost' in 'living cost index'
# [Substring wins] 'bird' in 'bird id'
# [Substring wins] 'ratio' in 'migration reason'
# [Substring wins] 'start' in 'start latitude'
# [Substring wins] 'start' in 'start longitude'
# [Substring wins] 'distance' in 'flight distance km'
# [Substring wins] 'duration' in 'flight duration hours'
# [Substring wins] 'average speed' in 'average speed kmph'
# [Substring wins] 'altitude' in 'maximum altitude m'
# [Substring wins] 'altitude' in 'min altitude m'
# [Substring wins] 'temperature' in 'temperature c'
# [Substring wins] 'appearance' in 'pressure hits plate appearances'
# [Substring wins] 'battery' in 'tag battery level %'
# [Substring wins] 'strength' in 'signal strength drawn b'
# [Substring wins] 'month' in 'migration start month'
# [Substring wins] 'month' in 'migration end month'
# [Substring wins] 'type' in 'tag type'
# [Substring wins] 'supply' in 'food supply level'
# [Substring wins] 'ratio' in 'migration interrupted'
# [Substring wins] 'weight' in 'tag weight games'
# [Substring wins] 'ratio' in 'migration success'
# [Substring wins] 'location' in 'recovery location known'
# [Substring wins] 'time' in 'recovery time days'
# [Substring wins] 'name' in 'app name'
# [Substring wins] 'time' in 'screen time min'
# [Substring wins] 'product' in 'is productive'
# [Substring wins] 'comment' in 'youtube comments'
# [Substring wins] 'average' in 'average width'
# [Substring wins] 'average' in 'average height'
# [Substring wins] 'width' in 'min width'
# [Substring wins] 'height' in 'min height'
# [Substring wins] 'width' in 'maximum width'
# [Substring wins] 'height' in 'maximum height'
# [Substring wins] 'format' in 'formats'
# [Substring wins] 'file' in 'corrupt files'
# [Substring wins] 'country' in 'country region'
# [Substring wins] 'gene' in 'genetic risk'
# [Substring wins] 'type' in 'cancer type'
# [Substring wins] 'treatment' in 'treatment cost usd'
# [Substring wins] 'years' in 'survival years'
# [Substring wins] 'score' in 'target severity score'
# [Substring wins] 'date' in 'job posted date'
# [Substring wins] 'locality' in 'company address locality'
# [Substring wins] 'address' in 'company address region'
# [Substring wins] 'company' in 'company name'
# [Substring wins] 'company' in 'company website'
# [Substring wins] 'description' in 'company description'
# [Substring wins] 'description' in 'job description text'
# [Substring wins] 'seniority' in 'seniority level'
# [Substring wins] 'title' in 'job title'
# [Substring wins] 'status' in 'marital status'
# [Substring wins] 'order' in 'application order'
# [Substring wins] 'time' in 'daytime'
# [Substring wins] 'mother' in 'mother s qualification'
# [Substring wins] 'father' in 'father s qualification'
# [Substring wins] 'occupation' in 'mother s occupation'
# [Substring wins] 'occupation' in 'father s occupation'
# [Substring wins] 'mission' in 'admission grade'
# [Substring wins] 'place' in 'displaced'
# [Substring wins] 'education' in 'educational special needs'
# [Substring wins] 'tuition' in 'tuition fees up to date'
# [Substring wins] 'ship' in 'scholarship holder'
# [Substring wins] 'nation' in 'international'
# [Substring wins] 'date' in 'birthdate'
# [Substring wins] 'area' in 'lv area'
# [Substring wins] 'settlement' in 'lv settlementname'
# [Substring wins] 'industry' in 'industryname'
# [Substring wins] 'child' in 'underagechildrencount'
# [Substring wins] 'family' in 'familystatus'
# [Substring wins] 'order' in 'order id'
# [Substring wins] 'sales' in 'total sales'
# [Substring wins] 'name' in 'customer name'
# [Substring wins] 'location' in 'customer location'
# [Substring wins] 'work' in 'work pressure'
# [Substring wins] 'average' in 'cumulative grade point average'
# [Substring wins] 'duration' in 'sleep duration'
# [Substring wins] 'family' in 'family history of mental illness'
# [Substring wins] 'date' in 'ref date'
# [Substring wins] 'type' in 'type of crop'
# [Substring wins] 'average' in 'average farm price'
# [Substring wins] 'average' in 'average yield'
# [Substring wins] 'area' in 'seeded area'
# [Substring wins] 'area' in 'seeded area'
# [Substring wins] 'value' in 'total farm value'
# [Substring wins] 'volume' in 'ai generated content volume'
# [Substring wins] 'revenue' in 'revenue increase due to ai'
# [Substring wins] 'collaboration' in 'human ai collaboration rate'
# [Substring wins] 'status' in 'regulation status'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'date' in 'datetime'
# [Substring wins] 'games' in 'seller games'
# [Substring wins] 'code' in 'postcode'
# [Substring wins] 'land' in 'landsize'
# [Substring wins] 'building' in 'building area'
# [Substring wins] 'year' in 'year built'
# [Substring wins] 'region' in 'regionname'
# [Substring wins] 'vehicle' in 'vehicle type'
# [Substring wins] 'capacity' in 'battery capacity strikeout wh'
# [Substring wins] 'percentage' in 'discount percentage'
# [Substring wins] 'name' in 'track name'
# [Substring wins] 'duration' in 'duration min'
# [Substring wins] 'mass' in 'body mass index'
# [Substring wins] 'activity' in 'physical activity level'
# [Substring wins] 'status' in 'smoking status'
# [Substring wins] 'family' in 'family history of diabetes'
# [Substring wins] 'station' in 'previous gestational diabetes'
# [Substring wins] 'created' in 'created at'
# [Substring wins] 'victory' in 'victory status'
# [Substring wins] 'code' in 'increment code'
# [Substring wins] 'rating' in 'white rating'
# [Substring wins] 'rating' in 'black rating'
# [Substring wins] 'name' in 'opening name'
# [Substring wins] 'number' in 'accident number'
# [Substring wins] 'date' in 'date and time'
# [Substring wins] 'vehicle' in 'number of motor vehicles'
# [Substring wins] 'number' in 'number of injuries'
# [Substring wins] 'number' in 'number of fatalities'
# [Substring wins] 'damage' in 'property damage'
# [Substring wins] 'description' in 'collision type description'
# [Substring wins] 'description' in 'weather description'
# [Substring wins] 'description' in 'illumination description'
# [Substring wins] 'address' in 'street address'
# [Substring wins] 'code' in 'harmful codes'
# [Substring wins] 'description' in 'harmful descriptions'
# [Substring wins] 'nation' in 'illu accidemination'
# [Substring wins] 'type' in 'collision type'
# [Substring wins] 'office' in 'reporting officer'
# [Substring wins] 'country' in 'meet country'
# [Substring wins] 'state' in 'meet state'
# [Substring wins] 'name' in 'meet name'
# [Substring wins] 'number' in 'review number'
# [Substring wins] 'name' in 'kepoi name'
# [Substring wins] 'name' in 'kepler name'
# [Substring wins] 'position' in 'koi disposition'
# [Substring wins] 'position' in 'koi pdisposition'
# [Substring wins] 'score' in 'koi score'
# [Substring wins] 'flag' in 'koi fpflag nt'
# [Substring wins] 'strength' in 'koi fpflag strength schedule'
# [Substring wins] 'flag' in 'koi fpflag carbon oxide'
# [Substring wins] 'flag' in 'koi fpflag ec'
# [Substring wins] 'period' in 'koi period'
# [Substring wins] 'period' in 'koi period err 1'
# [Substring wins] 'period' in 'koi period err 2'
# [Substring wins] 'time' in 'koi time 0 bike'
# [Substring wins] 'time' in 'koi time 0 bike err 1'
# [Substring wins] 'time' in 'koi time 0 bike err 2'
# [Substring wins] 'duration' in 'koi duration'
# [Substring wins] 'duration' in 'koi duration err 1'
# [Substring wins] 'duration' in 'koi duration err 2'
# [Substring wins] 'depth' in 'koi depth'
# [Substring wins] 'depth' in 'koi depth err 1'
# [Substring wins] 'depth' in 'koi depth err 2'
# [Substring wins] 'model' in 'koi model snr'
# [Substring wins] 'number' in 'koi tce plnt number'
# [Substring wins] 'name' in 'koi tce delivname'
# [Substring wins] 'battery' in 'battery power'
# [Substring wins] 'games' in 'four games'
# [Substring wins] 'weight' in 'mobile weight'
# [Substring wins] 'number' in 'number cores'
# [Substring wins] 'height' in 'px height'
# [Substring wins] 'width' in 'px width'
# [Substring wins] 'access' in 'random access memory'
# [Substring wins] 'description' in 'succint description hits'
# [Substring wins] 'description' in 'succint description wins'
# [Substring wins] 'time' in 'talk time'
# [Substring wins] 'games' in 'three games'
# [Substring wins] 'student' in 'student id'
# [Substring wins] 'activity' in 'physical activity hours per day'
# [Substring wins] 'category' in 'item category'
# [Substring wins] 'status' in 'order status'
# [Substring wins] 'price' in 'unit price'
# [Substring wins] 'price' in 'negotiated price'
# [Substring wins] 'state' in 'states'
# [Substring wins] 'case' in 'no of cases reported'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'case' in 'no of cases reported'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'case' in 'no of cases reported'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'victims' in 'no of victims'
# [Substring wins] 'parent' in 'parent status'
# [Substring wins] 'education' in 'mother education'
# [Substring wins] 'education' in 'father education'
# [Substring wins] 'mother' in 'mother job'
# [Substring wins] 'father' in 'father job'
# [Substring wins] 'time' in 'traveltime'
# [Substring wins] 'time' in 'studytime'
# [Substring wins] 'school' in 'schoolsup'
# [Substring wins] 'family' in 'family support'
# [Substring wins] 'free' in 'freetime'
# [Substring wins] 'class' in 'mssub class'
# [Substring wins] 'area' in 'lot area'
# [Substring wins] 'tree' in 'street'
# [Substring wins] 'shape' in 'lot shape'
# [Substring wins] 'land' in 'land contour'
# [Substring wins] 'land' in 'land slope'
# [Substring wins] 'type' in 'bldg type'
# [Substring wins] 'house' in 'house style'
# [Substring wins] 'year' in 'year built'
# [Substring wins] 'address' in 'year remod address'
# [Substring wins] 'style' in 'roof style'
# [Substring wins] 'type' in 'mas vnr type'
# [Substring wins] 'area' in 'mas vnr area'
# [Substring wins] 'type' in 'basement finance type 1'
# [Substring wins] 'type' in 'basement finance type 2'
# [Substring wins] 'area' in 'grade liv area'
# [Substring wins] 'place' in 'fireplaces'
# [Substring wins] 'place' in 'fireplace qu'
# [Substring wins] 'type' in 'garage type'
# [Substring wins] 'year' in 'garage year built'
# [Substring wins] 'area' in 'garage area'
# [Substring wins] 'work' in 'woodworking deck sf'
# [Substring wins] 'closed' in 'enclosed porch'
# [Substring wins] 'area' in 'pool area'
# [Substring wins] 'feature' in 'misc feature'
# [Substring wins] 'value' in 'misc value'
# [Substring wins] 'month' in 'month sold'
# [Substring wins] 'year' in 'year sold'
# [Substring wins] 'type' in 'sale type'
# [Substring wins] 'price' in 'sale price'
# [Substring wins] 'order' in 'order id'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'category' in 'sub category'
# [Substring wins] 'name' in 'customer name'
# [Substring wins] 'month' in 'year month'
# [Substring wins] 'score' in 'team score'
# [Substring wins] 'opponent' in 'opponent score'
# [Substring wins] 'cost' in 'elixir cost'
# [Substring wins] 'attack' in 'attack type'
# [Substring wins] 'industry' in 'target industry'
# [Substring wins] 'number' in 'number of affected users'
# [Substring wins] 'source' in 'attack source'
# [Substring wins] 'security' in 'security vulnerability type'
# [Substring wins] 'resolution' in 'incident resolution time'
# [Substring wins] 'station' in 'charging station id'
# [Substring wins] 'station' in 'charging station type'
# [Substring wins] 'model' in 'ev model'
# [Substring wins] 'capacity' in 'battery capacity'
# [Substring wins] 'start' in 'charging start time'
# [Substring wins] 'time' in 'charging end time'
# [Substring wins] 'duration' in 'charging duration'
# [Substring wins] 'cost' in 'charging cost'
# [Substring wins] 'station' in 'station utilization rate'
# [Substring wins] 'name' in 'item name'
# [Substring wins] 'price' in 'unit price'
# [Substring wins] 'cost' in 'total cost'
# [Substring wins] 'date' in 'purchase date'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'head' in 'headlines'
# [Substring wins] 'species' in 'species observed'
# [Substring wins] 'number' in 'number words'
# [Substring wins] 'number' in 'number unique words'
# [Substring wins] 'number' in 'number stopwords'
# [Substring wins] 'number' in 'number links'
# [Substring wins] 'domain' in 'number unique domains'
# [Substring wins] 'address' in 'number email addresses'
# [Substring wins] 'number' in 'number spelling errors'
# [Substring wins] 'number' in 'number urgent keywords'
# [Substring wins] 'rank' in 'rank 2025'
# [Substring wins] 'rank' in 'rank 2024'
# [Substring wins] 'institution' in 'institution name'
# [Substring wins] 'score' in 'academic reputation score'
# [Substring wins] 'rank' in 'academic reputation rank'
# [Substring wins] 'employer' in 'employer reputation score'
# [Substring wins] 'employer' in 'employer reputation rank'
# [Substring wins] 'student' in 'faculty student score'
# [Substring wins] 'student' in 'faculty student rank'
# [Substring wins] 'score' in 'citations per faculty score'
# [Substring wins] 'rank' in 'citations per faculty rank'
# [Substring wins] 'nation' in 'international faculty score'
# [Substring wins] 'nation' in 'international faculty rank'
# [Substring wins] 'student' in 'international students score'
# [Substring wins] 'student' in 'international students rank'
# [Substring wins] 'network' in 'international research network score'
# [Substring wins] 'network' in 'international research network rank'
# [Substring wins] 'score' in 'employment outcomes score'
# [Substring wins] 'rank' in 'employment outcomes rank'
# [Substring wins] 'score' in 'sustainability score'
# [Substring wins] 'rank' in 'sustainability rank'
# [Substring wins] 'score' in 'overall score'
# [Substring wins] 'mass' in 'body mass index'
# [Substring wins] 'reference' in 'customer reference id'
# [Substring wins] 'mount' in 'purchase amount'
# [Substring wins] 'date' in 'date purchase'
# [Substring wins] 'rating' in 'review rating'
# [Substring wins] 'number' in 'incident number'
# [Substring wins] 'date' in 'date of incident'
# [Substring wins] 'victims' in 'number of victims under 18'
# [Substring wins] 'victims' in 'number of victims over 18'
# [Substring wins] 'number' in 'number of offenders under 18'
# [Substring wins] 'number' in 'number of offenders over 18'
# [Substring wins] 'location' in 'offense location'
# [Substring wins] 'district' in 'council district'
# [Substring wins] 'product' in 'product code'
# [Substring wins] 'product' in 'product specification'
# [Substring wins] 'date' in 'inward date'
# [Substring wins] 'date' in 'dispatch date'
# [Substring wins] 'name' in 'customer name'
# [Substring wins] 'location' in 'customer location'
# [Substring wins] 'access' in 'random access memory'
# [Substring wins] 'type' in 'crop type'
# [Substring wins] 'temperature' in 'temperature c'
# [Substring wins] 'type' in 'irrigation type'
# [Substring wins] 'type' in 'fertilizer type'
# [Substring wins] 'mill' in 'pesticide usage milliliter'
# [Substring wins] 'date' in 'sowing date'
# [Substring wins] 'date' in 'harvest date'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'disease' in 'crop disease status'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'ratio' in 'generation time'
# [Substring wins] 'file size' in 'file size kb'
# [Substring wins] 'score' in 'style accuracy score'
# [Substring wins] 'hand' in 'is hand edited'
# [Substring wins] 'flag' in 'ethical concerns flag'
# [Substring wins] 'date' in 'creation date'
# [Substring wins] 'comment' in 'top comment'
# [Substring wins] 'name' in 'study name'
# [Substring wins] 'number' in 'sample number'
# [Substring wins] 'date' in 'date egg'
# [Substring wins] 'length' in 'culmen length'
# [Substring wins] 'depth' in 'culmen depth'
# [Substring wins] 'length' in 'flipper length'
# [Substring wins] 'mass' in 'body mass'
# [Substring wins] 'number' in 'delta 15 number'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'show' in 'show id'
# [Substring wins] 'date' in 'date added'
# [Substring wins] 'year' in 'release year'
# [Substring wins] 'river' in 'id driver'
# [Substring wins] 'date' in 'date ref'
# [Substring wins] 'date' in 'date last seen'
# [Substring wins] 'date' in 'date first seen'
# [Substring wins] 'date' in 'date interval maximum min'
# [Substring wins] 'races' in 'quantity races'
# [Substring wins] 'team' in 'quantity teams'
# [Substring wins] 'team' in 'id team'
# [Substring wins] 'race' in 'quantity last seen race'
# [Substring wins] 'position' in 'average grid position'
# [Substring wins] 'position' in 'median grid position'
# [Substring wins] 'position' in 'average position'
# [Substring wins] 'position' in 'median position'
# [Substring wins] 'position' in 'total position lift'
# [Substring wins] 'position' in 'average position lift'
# [Substring wins] 'position' in 'median position lift'
# [Substring wins] 'percentage' in 'percentage pole positition'
# [Substring wins] 'percentage' in 'percentage polewin'
# [Substring wins] 'pole' in 'qtd pole positition'
# [Substring wins] 'pole' in 'qtd polewin'
# [Substring wins] 'position' in 'average grid position race first 05'
# [Substring wins] 'position' in 'median grid position race first 05'
# [Substring wins] 'position' in 'average position race first 05'
# [Substring wins] 'position' in 'median position race first 05'
# [Substring wins] 'position' in 'total position lift race first 05'
# [Substring wins] 'position' in 'average position lift race first 05'
# [Substring wins] 'position' in 'median position lift race first 05'
# [Substring wins] 'percentage' in 'percentage pole positition race first 05'
# [Substring wins] 'percentage' in 'percentage polewin race first 05'
# [Substring wins] 'position' in 'average grid position race first 10'
# [Substring wins] 'position' in 'median grid position race first 10'
# [Substring wins] 'position' in 'average position race first 10'
# [Substring wins] 'position' in 'median position race first 10'
# [Substring wins] 'position' in 'total position lift race first 10'
# [Substring wins] 'position' in 'average position lift race first 10'
# [Substring wins] 'position' in 'median position lift race first 10'
# [Substring wins] 'percentage' in 'percentage pole positition race first 10'
# [Substring wins] 'percentage' in 'percentage polewin race first 10'
# [Substring wins] 'position' in 'average grid position race last 10'
# [Substring wins] 'position' in 'median grid position race last 10'
# [Substring wins] 'position' in 'average position race last 10'
# [Substring wins] 'position' in 'median position race last 10'
# [Substring wins] 'position' in 'total position lift race last 10'
# [Substring wins] 'position' in 'average position lift race last 10'
# [Substring wins] 'position' in 'median position lift race last 10'
# [Substring wins] 'percentage' in 'percentage pole positition race last 10'
# [Substring wins] 'percentage' in 'percentage polewin race last 10'
# [Substring wins] 'position' in 'average grid position race last 20'
# [Substring wins] 'position' in 'median grid position race last 20'
# [Substring wins] 'position' in 'average position race last 20'
# [Substring wins] 'position' in 'median position race last 20'
# [Substring wins] 'position' in 'total position lift race last 20'
# [Substring wins] 'position' in 'average position lift race last 20'
# [Substring wins] 'position' in 'median position lift race last 20'
# [Substring wins] 'percentage' in 'percentage pole positition race last 20'
# [Substring wins] 'percentage' in 'percentage polewin race last 20'
# [Substring wins] 'position' in 'average grid position race last 40'
# [Substring wins] 'position' in 'median grid position race last 40'
# [Substring wins] 'position' in 'average position race last 40'
# [Substring wins] 'position' in 'median position race last 40'
# [Substring wins] 'position' in 'total position lift race last 40'
# [Substring wins] 'position' in 'average position lift race last 40'
# [Substring wins] 'position' in 'median position lift race last 40'
# [Substring wins] 'percentage' in 'percentage pole positition race last 40'
# [Substring wins] 'percentage' in 'percentage polewin race last 40'
# [Substring wins] 'cave' in 'concave points'
# [Substring wins] 'cave' in 'concave points'
# [Substring wins] 'cave' in 'concave points'
# [Substring wins] 'language' in 'sign language'
# [Substring wins] 'type' in 'anomaly type'
# [Substring wins] 'score' in 'anomaly score'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'score' in 'confidence score'
# [Substring wins] 'width' in 'bounding box width'
# [Substring wins] 'height' in 'bounding box height'
# [Substring wins] 'mass' in 'body mass index'
# [Substring wins] 'length' in 'sepal length cm'
# [Substring wins] 'width' in 'sepal width cm'
# [Substring wins] 'length' in 'petal length cm'
# [Substring wins] 'width' in 'petal width cm'
# [Substring wins] 'time' in 'screen time type'
# [Substring wins] 'type' in 'day type'
# [Substring wins] 'average' in 'average screen time'
# [Substring wins] 'volume' in 'volume aapl'
# [Substring wins] 'volume' in 'volume amzn'
# [Substring wins] 'volume' in 'volume googl'
# [Substring wins] 'volume' in 'volume msft'
# [Substring wins] 'volume' in 'volume nvda'
# [Substring wins] 'date' in 'datetime'
# [Substring wins] 'head' in 'headline'
# [Substring wins] 'case' in 'total cases'
# [Substring wins] 'case' in 'new cases'
# [Substring wins] 'case' in 'tests per case'
# [Substring wins] 'nation' in 'total vaccinations'
# [Substring wins] 'hospital' in 'hospitalizations patients'
# [Substring wins] 'production' in 'reproduction rate'
# [Substring wins] 'media' in 'median age'
# [Substring wins] 'gross domestic product' in 'gross domestic product per capita'
# [Substring wins] 'person' in 'sales person'
# [Substring wins] 'mount' in 'amount'
# [Substring wins] 'ship' in 'boxes shipped'
# [Substring wins] 'time' in 'local time'
# [Substring wins] 'start' in 'startlist url'
# [Substring wins] 'result' in 'results url'
# [Substring wins] 'model' in 'model year'
# [Substring wins] 'vehicle' in 'electric vehicle type'
# [Substring wins] 'vehicle' in 'clean alternative fuel vehicle'
# [Substring wins] 'range' in 'electric range'
# [Substring wins] 'district' in 'legislative district'
# [Substring wins] 'vehicle' in 'dol vehicle id'
# [Substring wins] 'location' in 'vehicle location'
# [Substring wins] 'occupation' in 'what is your occupation'
# [Substring wins] 'media' in 'how many hours per day do you spend on social media'
# [Substring wins] 'relation' in 'how has social media affected your real life relationships'
# [Substring wins] 'profession' in 'do you use linked in forestry professional networking'
# [Substring wins] 'media' in 'which social media platforms do you use the most'
# [Substring wins] 'media' in 'do you feel that social media affects your mental health'
# [Substring wins] 'education' in 'parental level of education'
# [Substring wins] 'course' in 'test preparation course'
# [Substring wins] 'score' in 'mathematics score'
# [Substring wins] 'score' in 'reading score'
# [Substring wins] 'score' in 'writing score'
# [Substring wins] 'product' in 'product id'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'region' in 'supplier region'
# [Substring wins] 'time' in 'lead time days'
# [Substring wins] 'volume' in 'order volume units'
# [Substring wins] 'cost' in 'cost per unit'
# [Substring wins] 'supply' in 'supply risk score'
# [Substring wins] 'act score' in 'profit impact score'
# [Substring wins] 'source' in 'single source risk'
# [Substring wins] 'category' in 'kraljic category'
# [Substring wins] 'sales' in 'sodium sales'
# [Substring wins] 'sales' in 'eu sales'
# [Substring wins] 'sales' in 'jp sales'
# [Substring wins] 'other' in 'other sales'
# [Substring wins] 'sales' in 'global sales'
# [Substring wins] 'price' in 'miles price'
# [Substring wins] 'source' in 'source notes'
# [Substring wins] 'season' in 'seasonal availability'
# [Substring wins] 'power' in 'horse power'
# [Substring wins] 'attack' in 'space attack'
# [Substring wins] 'space' in 'space defense'
# [Substring wins] 'fight' in 'fire fighting weakness'
# [Substring wins] 'water' in 'water weakness'
# [Substring wins] 'fight' in 'fighting weakness'
# [Substring wins] 'ground' in 'ground weakness'
# [Substring wins] 'height' in 'height inches'
# [Substring wins] 'height' in 'height meters'
# [Substring wins] 'weight' in 'weight pounds'
# [Substring wins] 'weight' in 'weight kilograms'
# [Substring wins] 'gender' in 'gender male ratio'
# [Substring wins] 'type' in 'type 1'
# [Substring wins] 'type' in 'type 2'
# [Substring wins] 'classification' in 'classification information'
# [Substring wins] 'gene' in 'genetics'
# [Substring wins] 'number' in 'number immune'
# [Substring wins] 'number' in 'number not effective'
# [Substring wins] 'number' in 'number normal'
# [Substring wins] 'number' in 'number super effective'
# [Substring wins] 'class' in 'passenger class'
# [Substring wins] 'sibling' in 'siblings space'
# [Substring wins] 'parent' in 'parents children'
# [Substring wins] 'senior' in 'senior citizen'
# [Substring wins] 'service' in 'phone service'
# [Substring wins] 'service' in 'internet service'
# [Substring wins] 'security' in 'online security'
# [Substring wins] 'stream' in 'streaming television'
# [Substring wins] 'stream' in 'streaming movies'
# [Substring wins] 'month' in 'monthly charges'
# [Substring wins] 'movie' in 'movie title'
# [Substring wins] 'year' in 'release year'
# [Substring wins] 'average' in 'average rating'
# [Substring wins] 'number' in 'number of reviews'
# [Substring wins] 'review' in 'review highlights'
# [Substring wins] 'discovered' in 'how discovered'
# [Substring wins] 'meaning' in 'meaningful advice taken'
# [Substring wins] 'friend' in 'suggested to friends'
# [Substring wins] 'name' in 'recipe name'
# [Substring wins] 'ingredient' in 'ingredients'
# [Substring wins] 'time' in 'cooking time minutes'
# [Substring wins] 'ratio' in 'preparation time minutes'
# [Substring wins] 'restriction' in 'dietary restrictions'
# [Substring wins] 'company' in 'company id'
# [Substring wins] 'company' in 'company name'
# [Substring wins] 'missions' in 'carbon emissions'
# [Substring wins] 'water' in 'water usage'
# [Substring wins] 'code' in 'code module'
# [Substring wins] 'code' in 'code presentation'
# [Substring wins] 'type' in 'assessment type'
# [Substring wins] 'team' in 'home team'
# [Substring wins] 'score' in 'home score'
# [Substring wins] 'score' in 'away score'
# [Substring wins] 'team' in 'away team'
# [Substring wins] 'name' in 'item name'
# [Substring wins] 'price' in 'price per unit'
# [Substring wins] 'sales' in 'total sales value'
# [Substring wins] 'number' in 'number links'
# [Substring wins] 'number' in 'number words'
# [Substring wins] 'score' in 'sender score'
# [Substring wins] 'source' in 'water source type'
# [Substring wins] 'dissolved' in 'dissolved oxygen'
# [Substring wins] 'ratio' in 'lead concentration'
# [Substring wins] 'treatment' in 'water treatment method'
# [Substring wins] 'access' in 'access to clean water'
# [Substring wins] 'case' in 'diarrheal cases per 100 000 people'
# [Substring wins] 'case' in 'cholera cases per 100 000 people'
# [Substring wins] 'case' in 'typhoid cases per 100 000 people'
# [Substring wins] 'infant mortality' in 'infant mortality rate'
# [Substring wins] 'gross domestic product' in 'gross domestic product per capita'
# [Substring wins] 'access' in 'healthcare access index'
# [Substring wins] 'station' in 'gestation'
# [Substring wins] 'year' in 'release year'
# [Substring wins] 'month' in 'monthly listeners'
# [Substring wins] 'stream' in 'total streams'
# [Substring wins] 'stream' in 'total hours streamed'
# [Substring wins] 'duration' in 'average stream duration'
# [Substring wins] 'type' in 'platform type'
# [Substring wins] 'stream' in 'streams last 30 days'
# [Substring wins] 'product' in 'product id'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'brand' in 'brand name'
# [Substring wins] 'state' in 'stock state'
# [Substring wins] 'name' in 'color name'
# [Substring wins] 'category' in 'main category code'
# [Substring wins] 'material' in 'materials'
# [Substring wins] 'name' in 'full name'
# [Substring wins] 'date' in 'date of purchase'
# [Substring wins] 'mountain' in 'mountain device'
# [Substring wins] 'review' in 'customer review'
# [Substring wins] 'month' in 'customer tenure in months'
# [Substring wins] 'price' in 'unit price'
# [Substring wins] 'number' in 'number of times purchased'
# [Substring wins] 'revenue' in 'total revenue'
# [Substring wins] 'status' in 'customer churn status'
# [Substring wins] 'registration' in 'registration type'
# [Substring wins] 'ratio' in 'corporation name'
# [Substring wins] 'name' in 'trade name'
# [Substring wins] 'address' in 'business address'
# [Substring wins] 'address' in 'business address 2'
# [Substring wins] 'number' in 'phone number'
# [Substring wins] 'number' in 'number ase certified mechanics'
# [Substring wins] 'address' in 'tow storage address'
# [Substring wins] 'city' in 'tow storage city'
# [Substring wins] 'state' in 'tow storage state'
# [Substring wins] 'date' in 'issue date'
# [Substring wins] 'ratio' in 'expiration'
# [Substring wins] 'registration' in 'registration no'
# [Substring wins] 'team' in 'batting team'
# [Substring wins] 'team' in 'bowling team'
# [Substring wins] 'type' in 'wicket type'
# [Substring wins] 'play' in 'player dismissed'
# [Substring wins] 'field' in 'fielder'
# [Substring wins] 'eyes' in 'pain behind the eyes'
# [Substring wins] 'head' in 'headache'
# [Substring wins] 'head' in 'severe headache'
# [Substring wins] 'eyes' in 'pain behind eyes'
# [Substring wins] 'land' in 'swollen glands'
# [Substring wins] 'head' in 'sinus headache'
# [Substring wins] 'taste' in 'reduced smell and taste'
# [Substring wins] 'head' in 'throbbing headache'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'team' in 'team 1'
# [Substring wins] 'team' in 'team 2'
# [Substring wins] 'date' in 'match date'
# [Substring wins] 'score' in 'scorecard'
# [Substring wins] 'credit' in 'credit score'
# [Substring wins] 'mount' in 'loan amount'
# [Substring wins] 'ratio' in 'dti ratio'
# [Substring wins] 'status' in 'employment status'
# [Substring wins] 'date' in 'enabled date'
# [Substring wins] 'date' in 'deadline date'
# [Substring wins] 'description' in 'dataset description'
# [Substring wins] 'order' in 'order id'
# [Substring wins] 'date' in 'ship date'
# [Substring wins] 'ship' in 'ship mode'
# [Substring wins] 'name' in 'customer name'
# [Substring wins] 'product' in 'product id'
# [Substring wins] 'category' in 'sub category'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'radio' in 'hx radiothreapy'
# [Substring wins] 'product' in 'product id'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'price' in 'discounted price'
# [Substring wins] 'price' in 'actual price'
# [Substring wins] 'percentage' in 'discount percentage'
# [Substring wins] 'rating' in 'rating count'
# [Substring wins] 'product' in 'about product'
# [Substring wins] 'name' in 'user name'
# [Substring wins] 'review' in 'review id'
# [Substring wins] 'review' in 'review title'
# [Substring wins] 'review' in 'review content'
# [Substring wins] 'product' in 'product link'
# [Substring wins] 'income' in 'annual income'
# [Substring wins] 'score' in 'spending score'
# [Substring wins] 'domain' in 'has domain'
# [Substring wins] 'birth date' in 'has birth date'
# [Substring wins] 'name' in 'has short name'
# [Substring wins] 'name' in 'has first name'
# [Substring wins] 'name' in 'has last name'
# [Substring wins] 'access' in 'access to closed profile'
# [Substring wins] 'closed' in 'is profile closed'
# [Substring wins] 'name' in 'has nickname'
# [Substring wins] 'name' in 'has maiden name'
# [Substring wins] 'interest' in 'has interests'
# [Substring wins] 'book' in 'has books'
# [Substring wins] 'quote' in 'has quotes'
# [Substring wins] 'games' in 'has games'
# [Substring wins] 'movie' in 'has movies'
# [Substring wins] 'address' in 'can address as friend'
# [Substring wins] 'military service' in 'has military service'
# [Substring wins] 'hometown' in 'has hometown'
# [Substring wins] 'status' in 'marital status'
# [Substring wins] 'school' in 'has schools'
# [Substring wins] 'relative' in 'has relatives'
# [Substring wins] 'status' in 'has status'
# [Substring wins] 'average' in 'average likes'
# [Substring wins] 'ratio' in 'links ratio'
# [Substring wins] 'ratio' in 'hashtags ratio'
# [Substring wins] 'average' in 'average keywords'
# [Substring wins] 'average' in 'average text length'
# [Substring wins] 'ratio' in 'attachments ratio'
# [Substring wins] 'average' in 'average comments'
# [Substring wins] 'ratio' in 'reposts ratio'
# [Substring wins] 'ratio' in 'ads ratio'
# [Substring wins] 'average' in 'average views'
# [Substring wins] 'frequency' in 'posting frequency days'
# [Substring wins] 'number' in 'phone numbers ratio'
# [Substring wins] 'average' in 'average text uniqueness'
# [Substring wins] 'occupation' in 'has occupation'
# [Substring wins] 'occupation' in 'occupation type university'
# [Substring wins] 'occupation' in 'occupation type work'
# [Substring wins] 'person' in 'has personal data'
# [Substring wins] 'perimeter' in 'perimeter mean'
# [Substring wins] 'area' in 'area mean'
# [Substring wins] 'cave' in 'concave points mean'
# [Substring wins] 'perimeter' in 'perimeter se'
# [Substring wins] 'area' in 'area se'
# [Substring wins] 'cave' in 'concave points se'
# [Substring wins] 'perimeter' in 'perimeter worst'
# [Substring wins] 'area' in 'area worst'
# [Substring wins] 'cave' in 'concave points worst'
# [Substring wins] 'name' in 'competitorname'
# [Substring wins] 'price' in 'pricepercent'
# [Substring wins] 'mass' in 'body mass index'
# [Substring wins] 'price' in 'new price'
# [Substring wins] 'price' in 'used price'
# [Substring wins] 'interest' in 'interest rate'
# [Substring wins] 'number' in 'number of major vessels'
# [Substring wins] 'type' in 'thalassemia type'
# [Substring wins] 'number' in 'number of people with hiv'
# [Substring wins] 'year' in 'year of estimate'
# [Substring wins] 'time' in 'lead time'
# [Substring wins] 'date' in 'arrival date year'
# [Substring wins] 'month' in 'arrival date month'
# [Substring wins] 'number' in 'arrival date week number'
# [Substring wins] 'month' in 'arrival date day of month'
# [Substring wins] 'child' in 'children'
# [Substring wins] 'channel' in 'distribution channel'
# [Substring wins] 'guest' in 'is repeated guest'
# [Substring wins] 'book' in 'previous bookings not canceled'
# [Substring wins] 'type' in 'reserved room type'
# [Substring wins] 'type' in 'assigned room type'
# [Substring wins] 'book' in 'booking changes'
# [Substring wins] 'type' in 'deposit type'
# [Substring wins] 'type' in 'customer type'
# [Substring wins] 'space' in 'required car parking spaces'
# [Substring wins] 'status' in 'reservation status'
# [Substring wins] 'status' in 'reservation status date'
# [Substring wins] 'time' in 'timestamp'
# [Substring wins] 'volume' in 'bnb usdt 1 hits volume'
# [Substring wins] 'volume' in 'btc usdt 1 hits volume'
# [Substring wins] 'volume' in 'doge usdt 1 hits volume'
# [Substring wins] 'volume' in 'ethnology usdt 1 hits volume'
# [Substring wins] 'volume' in 'solution usdt 1 hits volume'
# [Substring wins] 'volume' in 'xrp usdt 1 hits volume'
# [Substring wins] 'volume' in 'volume ibovespa'
# [Substring wins] 'volume' in 'volume ipc mexico'
# [Substring wins] 'volume' in 'volume dax'
# [Substring wins] 'volume' in 'volume nasdaq'
# [Substring wins] 'volume' in 'volume russell 2000'
# [Substring wins] 'volume' in 'volume vix'
# [Substring wins] 'volume' in 'volume cac 40'
# [Substring wins] 'volume' in 'volume euro stoxx 50'
# [Substring wins] 'volume' in 'volume dow jones'
# [Substring wins] 'volume' in 'volume ftse 100'
# [Substring wins] 'volume' in 'volume sptsx'
# [Substring wins] 'space' in 'close space 500'
# [Substring wins] 'space' in 'high space 500'
# [Substring wins] 'space' in 'low space 500'
# [Substring wins] 'space' in 'open space 500'
# [Substring wins] 'volume' in 'volume space 500'
# [Substring wins] 'interest' in 'open interest'
# [Substring wins] 'duration' in 'sleep duration'
# [Substring wins] 'type' in 'diet type'
# [Substring wins] 'time' in 'daily screen time'
# [Substring wins] 'frequency' in 'exercise frequency'
# [Substring wins] 'time' in 'reaction time'
# [Substring wins] 'score' in 'memory test score'
# [Substring wins] 'score' in 'cognitive score'
# [Substring wins] 'score' in 'ai predicted score'
# [Substring wins] 'case' in 'case id'
# [Substring wins] 'date' in 'date reported'
# [Substring wins] 'type' in 'pollutant type'
# [Substring wins] 'ratio' in 'pollutant concentration milligrams kg'
# [Substring wins] 'temperature' in 'temperature c'
# [Substring wins] 'type' in 'crop type'
# [Substring wins] 'industry' in 'nearby industry'
# [Substring wins] 'source' in 'water source type'
# [Substring wins] 'organ' in 'soil organic matter %'
# [Substring wins] 'disease' in 'disease type'
# [Substring wins] 'disease' in 'disease severity'
# [Substring wins] 'symptom' in 'health symptoms'
# [Substring wins] 'gender' in 'gender most affected'
# [Substring wins] 'case' in 'case resolved'
# [Substring wins] 'date' in 'date posted'
# [Substring wins] 'type' in 'work type'
# [Substring wins] 'type' in 'employment type'
# [Substring wins] 'mission' in 'date of admission'
# [Substring wins] 'mount' in 'billing amount'
# [Substring wins] 'number' in 'room number'
# [Substring wins] 'mission' in 'admission type'
# [Substring wins] 'discharge' in 'discharge date'
# [Substring wins] 'result' in 'test results'
# [Substring wins] 'house' in 'household id'
# [Substring wins] 'house' in 'household size'
# [Substring wins] 'temperature' in 'average temperature c'
# [Substring wins] 'location' in 'location type'
# [Substring wins] 'income' in 'income bracket'
# [Substring wins] 'education' in 'education level'
# [Substring wins] 'interest' in 'interest tags'
# [Substring wins] 'time' in 'app usage time min'
# [Substring wins] 'time' in 'app usage time label'
# [Substring wins] 'ratio' in 'swipe right ratio'
# [Substring wins] 'file' in 'profile pics count'
# [Substring wins] 'length' in 'bio length'
# [Substring wins] 'time' in 'swipe time of day'
# [Substring wins] 'years' in 'playing years'
# [Substring wins] 'play' in 'playing often'
# [Substring wins] 'play' in 'playing hours'
# [Substring wins] 'games' in 'playing games'
# [Substring wins] 'revenue' in 'parent revenue'
# [Substring wins] 'education' in 'father education'
# [Substring wins] 'education' in 'mother education'
# [Substring wins] 'price' in 'open price'
# [Substring wins] 'price' in 'close price'
# [Substring wins] 'volume' in 'trading volume'
# [Substring wins] 'gross domestic product' in 'gross domestic product growth'
# [Substring wins] 'interest' in 'interest rate'
# [Substring wins] 'government' in 'government debt'
# [Substring wins] 'price' in 'crude oil price'
# [Substring wins] 'price' in 'gold price'
# [Substring wins] 'state' in 'real estate index'
# [Substring wins] 'sales' in 'retail sales'
# [Substring wins] 'capital' in 'venture capital funding'
# [Substring wins] 'score' in 'jee main score'
# [Substring wins] 'score' in 'jee advanced score'
# [Substring wins] 'average' in 'mock test score average'
# [Substring wins] 'class' in 'class 12 percent'
# [Substring wins] 'coach' in 'coaching institute'
# [Substring wins] 'family' in 'family income'
# [Substring wins] 'education' in 'parent education'
# [Substring wins] 'location' in 'location type'
# [Substring wins] 'mission' in 'admission taken'
# [Substring wins] 'house' in 'house price index'
# [Substring wins] 'ratio' in 'affordability ratio'
# [Substring wins] 'gross domestic product' in 'gross domestic product growth'
# [Substring wins] 'population' in 'population growth'
# [Substring wins] 'construction' in 'construction index'
# [Substring wins] 'price' in 'consumer price index'
# [Substring wins] 'disease' in 'heart disease'
# [Substring wins] 'type' in 'work type'
# [Substring wins] 'residence' in 'residence type'
# [Substring wins] 'average' in 'average glucose level'
# [Substring wins] 'mass' in 'body mass index'
# [Substring wins] 'status' in 'smoking status'
# [Substring wins] 'event' in 'eventid'
# [Substring wins] 'code' in 'ccode'
# [Substring wins] 'country' in 'countryname'
# [Substring wins] 'start' in 'startdate'
# [Substring wins] 'date' in 'enddate'
# [Substring wins] 'type' in 'etype'
# [Substring wins] 'actor' in 'actor 1'
# [Substring wins] 'actor' in 'actor 2'
# [Substring wins] 'actor' in 'actor 3'
# [Substring wins] 'part' in 'npart'
# [Substring wins] 'note' in 'issuenote'
# [Substring wins] 'source' in 'nsource'
# [Substring wins] 'event' in 'female event'
# [Substring wins] 'code' in 'coder'
# [Substring wins] 'comment' in 'geography comments'
# [Substring wins] 'location' in 'location precision'
# ...
# [Substring wins] 'time' in 'time left'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'bridge' in 'northbridge'
# [Substring wins] 'bridge' in 'southbridge'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'price' in 'average price'
# [Substring wins] 'location' in 'office location'
# [Substring wins] 'game' in 'per game'
# [Substring wins] 'date' in 'date available'
# [Substring wins] 'project' in 'projects'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'plays'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'owns' in 'rush touchdowns'
# [Substring wins] 'owns' in 'receive touchdowns'
# [Substring wins] 'owns' in 'total touchdowns'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'owns' in 'rush touchdowns'
# [Substring wins] 'owns' in 'receive touchdowns'
# [Substring wins] 'owns' in 'total touchdowns'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'trip' in 'triple'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'rating' in 'rivals rating'
# [Substring wins] 'video' in 'videos'
# [Substring wins] 'position' in 'position rank'
# [Substring wins] 'state' in 'state rank'
# [Substring wins] 'date' in 'visit date'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'version' in 'file version'
# [Substring wins] 'name' in 'ride name'
# [Substring wins] 'class' in 'classification'
# [Substring wins] 'category' in 'rider category'
# [Substring wins] 'address' in 'internet protocol address'
# [Substring wins] 'number' in 'as number'
# [Substring wins] 'name' in 'tournament'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'project' in 'project name'
# [Substring wins] 'number' in 'approval number'
# [Substring wins] 'date' in 'approval date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'class number'
# [Substring wins] 'course' in 'course title'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'dates de volume'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'customer' in 'customer comment'
# [Substring wins] 'number' in 'photos any number 1 or more 5 or more 10 or more 15 or more 20 or more 25 or more 0 no photo'
# [Substring wins] 'price' in 'show price'
# [Substring wins] 'status' in 'status active any active'
# [Substring wins] 'play' in 'display nearby'
# [Substring wins] 'product' in 'product type'
# [Substring wins] 'date' in 'update'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'driver name'
# [Substring wins] 'stage' in 'postage and handling'
# [Substring wins] 'item' in 'each additional item'
# [Substring wins] 'name' in 'tournaments played'
# [Substring wins] 'position' in 'average position'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'calories' in 'miles points calories miles score'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'calories' in 'points calories miles score'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'number' in 'accession number'
# [Substring wins] 'name' in 'file name'
# [Substring wins] 'number' in 'collector and number'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'price' in 'trade price'
# [Substring wins] 'country' in 'rank within country'
# [Substring wins] 'number' in 'srnumber'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'grant' in 'granted'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'name' in 'soldier name'
# [Substring wins] 'number' in 'pension number'
# [Substring wins] 'location' in 'location code'
# [Substring wins] 'code' in 'channel code'
# [Substring wins] 'result' in 'result date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'free' in 'free throw attempts'
# [Substring wins] 'free' in 'free throws %'
# [Substring wins] 'person' in 'personal fouls'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'free' in 'free throws'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'error' in 'errors field goals %'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'school' in 'miles from home school'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'male' in 'male religious'
# [Substring wins] 'female' in 'female religious'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'reviews' in 'abreviews'
# [Substring wins] 'person' in 'personal fouls'
# [Substring wins] 'appearance' in 'plate appearances'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'name' in 'scientific name'
# [Substring wins] 'name' in 'common name'
# [Substring wins] 'instrument' in 'cms instruments'
# [Substring wins] 'image' in 'image quality modes'
# [Substring wins] 'number' in 'number of images'
# [Substring wins] 'name' in 'common name'
# [Substring wins] 'name' in 'official trade name'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'date' in 'ex date'
# [Substring wins] 'date' in 'record date'
# [Substring wins] 'date' in 'payment date'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'free' in 'free throw attempts'
# [Substring wins] 'free' in 'free throws %'
# [Substring wins] 'person' in 'personal fouls'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'size' in 'piston size'
# [Substring wins] 'city' in 'capacity'
# [Substring wins] 'service' in 'services'
# [Substring wins] 'game' in 'points per game'
# [Substring wins] 'date' in 'last updated'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'address' in 'email address'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'line' in 'command line switch'
# [Substring wins] 'line' in 'command line argument'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'event' in 'event date'
# [Substring wins] 'size' in 'box size'
# [Substring wins] 'city' in 'capacity'
# [Substring wins] 'height' in 'width and height'
# [Substring wins] 'area' in 'protected area'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'schedule' in 'schedule points'
# [Substring wins] 'date' in 'date and time'
# [Substring wins] 'play' in 'teams playing'
# [Substring wins] 'code' in 'sale code'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'game' in 'games batting'
# [Substring wins] 'trip' in 'triple'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'players'
# [Substring wins] 'version' in 'versions'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'box name'
# [Substring wins] 'city' in 'nearby city'
# [Substring wins] 'name' in 'user name'
# [Substring wins] 'name' in 'real name'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'city' in 'capacity'
# [Substring wins] 'number' in 'number of bills'
# [Substring wins] 'members' in 'rank of 448 members'
# [Substring wins] 'model' in 'sub model'
# [Substring wins] 'state' in 'percent of state employment'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'result' in 'results'
# [Substring wins] 'video' in 'videos'
# [Substring wins] 'blog' in 'blogs'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'description' in 'succint description versus miss'
# [Substring wins] 'order' in 'call order'
# [Substring wins] 'project' in 'project number'
# [Substring wins] 'number' in 'control number'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'version' in 'game version'
# [Substring wins] 'name' in 'filename'
# [Substring wins] 'author' in 'authors'
# [Substring wins] 'author' in 'author shares'
# [Substring wins] 'price' in 'average price'
# [Substring wins] 'date' in 'date filed'
# [Substring wins] 'number' in 'file number'
# [Substring wins] 'status' in 'status date'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'distribution' in 'distribution period'
# [Substring wins] 'head' in 'column heading'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'error' in 'ig errors strikeout u'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'number' in 'number stocked'
# [Substring wins] 'number' in 'no number'
# [Substring wins] 'number' in 'no number'
# [Substring wins] 'application' in 'jmx application programming interface function'
# [Substring wins] 'application' in 'extensibility application programming interface function'
# [Substring wins] 'title' in 'side drawn titles'
# [Substring wins] 'season' in 'season points'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'image' in 'click images below to enlarge'
# [Substring wins] 'number' in 'part number'
# [Substring wins] 'application' in 'model application'
# [Substring wins] 'name' in 'route name'
# [Substring wins] 'number' in 'number of bolts'
# [Substring wins] 'number' in 'photos any number 1 or more 5 or more 10 or more 15 or more 20 or more 25 or more 0 no photo'
# [Substring wins] 'price' in 'show price'
# [Substring wins] 'status' in 'status active any active'
# [Substring wins] 'play' in 'display nearby'
# [Substring wins] 'line' in 'line up'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'calories' in 'miles calories miles score'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'lastname'
# [Substring wins] 'name' in 'shirt name'
# [Substring wins] 'date' in 'birthdate'
# [Substring wins] 'error' in 'errors mail'
# [Substring wins] 'address' in 'name and address'
# [Substring wins] 'telephone' in 'telephone number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'item number'
# [Substring wins] 'position' in 'peak position'
# [Substring wins] 'date' in 'dates served'
# [Substring wins] 'name' in 'tag name'
# [Substring wins] 'position' in 'position â'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'rank number'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'place' in 'place %'
# [Substring wins] 'completed' in 'sim dpschar i lv lchar level challenge score ach points pet score total damage done total damage received total healing done total healing received total kills total kills that grant experience or honor damage score at the proving grounds endless tank score at the proving grounds endless healer score at the proving grounds endless rated battlegrounds played rated battlegrounds won battlegrounds played battlegrounds won arenas played arenas won 2 v 2 matches 2 v 2 victories 3 v 3 matches 3 v 3 victories 5 v 5 matches 5 v 5 victories highest 2 man personal rating highest 3 man personal rating highest 5 man personal rating duels won duels lost battleground honorable kills total honorable kills total deaths from opposite faction pet battles won at maximum level pv p pet battles won at maximum level pv p pet battles won through find battle quests completed daily quests completed'
# [Substring wins] 'pathology' in 'pathology in user interface'
# [Substring wins] 'language' in 'language key'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'free' in 'free throw attempts'
# [Substring wins] 'free' in 'free throws %'
# [Substring wins] 'person' in 'personal fouls'
# [Substring wins] 'country' in 'country â ²'
# [Substring wins] 'language' in 'primary language'
# [Substring wins] 'number' in 'number produit'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'date' in 'tick date'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'number' in 'model number'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'time' in 'start stop times'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'error' in 'errors'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'color' in 'colors'
# [Substring wins] 'class' in 'ihsaa class'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'artist' in 'artist title'
# [Substring wins] 'comment' in 'comments'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'model' in 'model year'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'price' in 'priced from'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'date' in 'ex date'
# [Substring wins] 'date' in 'record date'
# [Substring wins] 'date' in 'payment date'
# [Substring wins] 'date' in 'declared date'
# [Substring wins] 'product' in 'product code'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'last name'
# [Substring wins] 'name' in 'first name'
# [Substring wins] 'position' in 'abbreviated position'
# [Substring wins] 'play' in 'player'
# [Substring wins] 'state' in 'state code'
# [Substring wins] 'state' in 'state name'
# [Substring wins] 'name' in 'ã â â name'
# [Substring wins] 'title' in 'song title'
# [Substring wins] 'line' in 'command line'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'ticket' in 'tickets'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'appearance' in 'plate appearances'
# [Substring wins] 'opponent' in 'opponent average'
# [Substring wins] 'opponent' in 'opponent on-base percentage'
# [Substring wins] 'opponent' in 'opponent slugging percentage'
# [Substring wins] 'opponent' in 'opponent tav'
# [Substring wins] 'play' in 'batting average on balls in play'
# [Substring wins] 'position' in 'position adj'
# [Substring wins] 'place' in 'value over replacement'
# [Substring wins] 'appearance' in 'plate appearances'
# [Substring wins] 'trip' in 'triple'
# [Substring wins] 'organization' in 'international organization for standardization'
# [Substring wins] 'place' in 'value over replacement'
# [Substring wins] 'winner' in 'winners'
# [Substring wins] 'comment' in 'commentary'
# [Substring wins] 'value' in 'assessed value'
# [Substring wins] 'game' in 'games played'
# [Substring wins] 'game' in 'games started'
# [Substring wins] 'person' in 'personal fouls'
# [Substring wins] 'product' in 'product name'
# [Substring wins] 'order' in 'order size'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'error' in 'ao errors'
# [Substring wins] 'value' in 'reasonable values'
# [Substring wins] 'opponent' in 'opponent in the final'
# [Substring wins] 'size' in 'stocking size'
# [Substring wins] 'item' in 'item level'
# [Substring wins] 'date' in 'dates'
# [Substring wins] 'time' in 'times'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'error' in 'errors'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'trip' in 'triple'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'event' in 'event name'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games'
# [Substring wins] 'appearance' in 'plate appearances'
# [Substring wins] 'trip' in 'triple'
# [Substring wins] 'product' in 'gross domestic product'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'monday' in 'monday 5'
# [Substring wins] 'tuesday' in 'tuesday 6'
# [Substring wins] 'wednesday' in 'wednesday 6'
# [Substring wins] 'thursday' in 'thursday 6'
# [Substring wins] 'monday' in 'monday 11'
# [Substring wins] 'tuesday' in 'tuesday 11'
# [Substring wins] 'wednesday' in 'wednesday 11'
# [Substring wins] 'thursday' in 'thursday 11'
# [Substring wins] 'name' in 'unnamed'
# [Substring wins] 'game' in 'games played'

# %%
header = "au release date"
matches = [label for label in dbpedia_labels if (label in header or header in label) and len(label) >= 4]
matches = sorted(matches, key=lambda x: (len(x.split()), len(x)), reverse=True)
print(matches)
# Out:
# ['release date', 'date']

# %% [markdown]
# FinalFormat

# %%
def analysis_of_column(ColumnFormat, DescriptionFormat, DescriptionKeyword, index_value):
    if ColumnFormat is None and DescriptionFormat is None:
        return 'NaN'

    # If either is 'None', choose the one that has a value
    if pd.isnull(ColumnFormat):
        return DescriptionFormat
    elif pd.isnull(DescriptionFormat):
        return ColumnFormat
  
    # Prioritize 'categorical' over 'numerical', but prefer specific numeric types in DescriptionKeyword
    if ColumnFormat == 'categorical' and DescriptionFormat == 'numerical':
        if DescriptionKeyword in ['float', 'double']:
            return DescriptionFormat
        return ColumnFormat
    
    # If one is 'string' and the other is not, choose the one that is not 'string'
    if ColumnFormat == 'string' and DescriptionFormat not in [None, 'string', 'NaN']:
        return DescriptionFormat
    elif DescriptionFormat == 'string' and ColumnFormat not in [None, 'string', 'NaN']:
        return ColumnFormat

    # If one is 'hour' and the other is numerical, choose numerical'
    if ColumnFormat == 'hour' and DescriptionFormat.startswith("numerical"):
        return DescriptionFormat
    elif DescriptionFormat == 'hour' and ColumnFormat.startswith("numerical"):
        return ColumnFormat
    
    # Datetime should always win
    if ColumnFormat == 'datetime' or DescriptionFormat == 'datetime':
        return 'datetime'

    # ID column should always win
    if ColumnFormat == "IDcolumn" or DescriptionFormat == "IDcolumn":
        return "IDcolumn"
    
    # percentage should always win
    if ColumnFormat == "percentage" or DescriptionFormat == "percentage":
        return "percentage"
    
    # binary should always win
    if ColumnFormat == 'binary' or DescriptionFormat == 'binary':
        return 'binary' 

    # If both are 'numerical' or if ColumnFormat is in the predefined list, return ColumnFormat
    if (ColumnFormat.startswith("numerical") and DescriptionFormat.startswith("numerical")) or \
       ColumnFormat in ["phone", "month", "date", "weekday", "week", "year",
                        "country", "state", "city", "street", "name",
                        "latitude", "longitude", "postalcode", "URLformat","IPformat", 
                        "E-mailformat", "binary"]:
        return ColumnFormat
    elif ColumnFormat in ["age"] and DescriptionFormat not in ['categorical']:
        return ColumnFormat
    # If no exceptions apply, return the value from "DescriptionFormat"
    else:
        return DescriptionFormat

# Apply the function to create the new column
analysed_columns_df['FinalFormat'] = analysed_columns_df.apply(
    lambda row: analysis_of_column(
        row['ColumnFormat'],
        row['DescriptionFormat'],
        row['DescriptionKeyword'],
        row['dataset_index']),  
    axis=1
)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-11-17 19:06:28

# %% [markdown]
# Identify Origin

# %%
def identify_origin(row):
    analysis_col = row['FinalFormat']
    ColumnFormat = row['ColumnFormat']
    DescriptionFormat = row['DescriptionFormat']

    # Check if the value in 'FinalFormat' came from 'ColumnFormat'
    if pd.notnull(ColumnFormat) and analysis_col == ColumnFormat:
        return row['ColumnKeyword']

    # Check if the value in 'FinalFormat' came from 'DescriptionFormat'
    elif pd.notnull(DescriptionFormat) and analysis_col == DescriptionFormat:
        return row['DescriptionKeyword']

    # If none of the above conditions are met, return NaN or any default value you prefer
    else:
        return 'NaN'

# Create the new column 'SourceKeyword' in analysed_columns_df
analysed_columns_df['SourceKeyword'] = analysed_columns_df.apply(identify_origin, axis=1)
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-11-17 19:06:45

# %% [markdown]
# Save results

# %%
# Save the results to a new Excel file
analysed_columns_df.to_excel(analysed_columns_file_path, index=False)

from datetime import datetime
print(f"Last run on: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# Last run on: 2025-11-17 19:07:32
